# %%
import os
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
from icecream import ic
import json
from datetime import datetime
from copy import deepcopy
load_dotenv()
# Out:
# True

# %% [markdown]
# ## load variables - swales
# - data folder
# - cleaned_df - for only swales
# - json template
# -

# %%
data_folder = os.path.join(os.getcwd(),'data')
cleaned_csv = os.path.join(data_folder, 'final_range_data.csv')
dff = pd.read_csv(cleaned_csv)

#lambda function to filter for swales
#for each row, is it a list/str, then is 'swales' in it, if so, return the df.
cleaned_df = dff[
    dff["land_use_selection-intervention"]
    .apply(lambda x: isinstance(x, (list, str)) and "swales" in x)
]

#swales datasets
swales_df = pd.read_csv(os.path.join(data_folder, 'brics_csvs', 'cleaned_trees_grasses_swales.csv'))

TEMPLATE_FILE = os.path.join(data_folder,"halfmoon_json_template.json")
with open(TEMPLATE_FILE, "r") as f:
    template = json.load(f)

# %% [markdown]
# ## check swales count

# %%
x = dff["land_use_selection-intervention"]
count = 0
for idx, i in enumerate(list(x)):
    if 'swales' in i:
        count += 1
        ic(i, count)

ic('swales count',len(cleaned_df))
# Out:
# ic| i: 'halfmoons swales water_points', count: 1
# ic| i: 'halfmoons swales soil_bunds water_points', count: 2
# ic| i: 'halfmoons swales', count: 3
# ic| i: 'halfmoons swales', count: 4
# ic| i: 'halfmoons gabions water_points swales gulley_plugging'
#     count: 5
# ic| i: 'swales', count: 6
# ic| i: 'swales', count: 7
# ic| i: 'halfmoons swales', count: 8
# ic| i: 'halfmoons swales water_points', count: 9
# ic| i: 'swales', count: 10
# ic| i: 'swales', count: 11
# ic| i: 'swales', count: 12
# ic| i: 'swales', count: 13
# ic| i: 'halfmoons swales contour_planting gulley_plugging water_points'
#     count: 14
# ic| i: 'swales', count: 15
# ic| i: 'halfmoons swales water_points', count: 16
# ic| i: 'halfmoons swales', count: 17
# ic| i: 'halfmoons swales', count: 18
# ic| i: 'halfmoons swales', count: 19
# ic| i: 'halfmoons swales soil_bunds contour_planting water_points'
#     count: 20
# ic| i: 'halfmoons swales gulley_plugging', count: 21
# ic| i: 'halfmoons swales gulley_plugging', count: 22
# ic| i: 'halfmoons swales gulley_plugging', count: 23
# ic| i: 'halfmoons swales gulley_plugging', count: 24
# ic| i: 'halfmoons swales gulley_plugging', count: 25
# ic| i: 'halfmoons swales gulley_plugging', count: 26
# ic| i: 'halfmoons swales gulley_plugging', count: 27
# ic| i: 'halfmoons swales gulley_plugging', count: 28
# ic| i: 'halfmoons swales gulley_plugging', count: 29
# ic| i: 'swales halfmoons gulley_plugging', count: 30
# ic| i: 'halfmoons swales gulley_plugging', count: 31
# ic| i: 'halfmoons swales gulley_plugging', count: 32
# ic| i: 'halfmoons swales gulley_plugging', count: 33
# ic| i: 'halfmoons swales gulley_plugging', count: 34
# ic| i: 'halfmoons swales gulley_plugging', count: 35
# ic| i: 'halfmoons swales gulley_plugging', count: 36
# ic| i: 'halfmoons swales gulley_plugging', count: 37
# ic| i: 'halfmoons swales gulley_plugging', count: 38
# ic| i: 'halfmoons swales gulley_plugging', count: 39
# ic| i: 'halfmoons swales gulley_plugging', count: 40
# ic| i: 'halfmoons swales gulley_plugging', count: 41
# ic| i: 'halfmoons swales', count: 42
# ic| i: 'swales', count: 43
# ic| i: 'halfmoons swales', count: 44
# ic| i: 'halfmoons swales', count: 45
# ic| 'swales count', len(cleaned_df): 45
# ('swales count', 45)

# %% [markdown]
# ## enumerators

# %%
#sorted(list(dff['basic_info-name'].unique()))
##empty name and key dictionary
names_dict = {}
for idx, row in dff.iterrows():
    #ic({row["KEY"], row["basic_info-name"]})
    names_dict[row["KEY"]] = row["basic_info-name"]
#ic(names_dict)
name_uname_dict = {
    "Zakariye haji ali": "abdullahi.hassan@mardo.org", 
    "Issack Idow Ibrahim": "abdullahi.hassan@mardo.org",
    "Abdullahi Hassan Adan": "abdullahi.hassan@mardo.org",
    "Abdikheir Mohamed": "mukhtar.yusuf23",
    "Abdikheir Mohamed Ali": "mukhtar.yusuf23",
    "Abdikheir Mohamed Dahir": "mukhtar.yusuf23",
    "Ali": "mukhtar.yusuf23",
    "Ali Adan": "mukhtar.yusuf23",
    "Ali Aden": "mukhtar.yusuf23",
    "Fathi": "mukhtar.yusuf23", 
    "Fathi Abdirashid": "mukhtar.yusuf23",
    "Ahmed Omar Hassan": "AhmedOmar",
    "Maria Abdirahman Ali": "AhmedOmar",
    "ABSHIR ABDULLAH ALI": "Ahil",
    "Ahmed Ibrahim": "JubaFoundation",
    "Ahmed Ibrahim Mohamed": "JubaFoundation",
    "Abdiaziz Adan Hassa": "guudow",
    "Abdiaziz Adan Hassan": "guudow",
    "Abdi Hassan Adan": "AbdiHassan",
    "Abdullahi": "sharif1234",
    "Abdirashid Sheikh Mohamed": "NRMO",
    "Abdullahi Sharif": "sharif1234",
    "Abdullahi Sharif LLG": "sharif1234",
    "Abdullahi Sharif Noor LLG": "sharif1234",
    "Abdijalil": "Csxaashi",
    "Abdijalil said": "Csxaashi",
    "Abdikarim Mohamed Ismail": "samandoulgou",
    "Abdikarin Mohamed Ismail": "samandoulgou",
    "Hassan Omar Khadhib": "Khadhib",
    "Hassan Omar Khadhibr": "Khadhib",
    "Jamal Ali": "JamalAli",
    "Jamal Ali Tagal": "JamalAli",
    "Mohamud Abdullahi Ali": "Mohamud",
    "Moulid Abdullahi Abdi": "Moulidwadani",
    "Muktar Mohamednoor Rage": "Mrage1997",
    "Osman Ebey Omar": "iibey",
    "Yusuf Mahi munye": "Mcnbdn617660",
    "abdullahi Sharif LLG": "sharif1234",
    "osman Ebey Omar": "iibey",
}

## match and replace names with usernames
for k, v in names_dict.items():
    for key, value in name_uname_dict.items():
        if v == key:
            names_dict[k] = value
#ic(names_dict)

##enumerator dictionary
enumerator = {
        "id": 3726,
        "first_name": "First",
        "last_name": "Last",
        "gender": "Male",
        "age_category": "18 - 35",
        "phone_number": "0e15704046",
        "email": "test_mail@gmail.com",
        "country": "test",
        "organization": "Test",
        "username": "test",
        "type": "ENUMERATOR"
    }

enums = []
#create enumerator jsons
for key, value in names_dict.items():
    e = deepcopy(enumerator)
    e['username'] = value
    e['key'] = key
    enums.append(e)

ic(enums)
# Out:
# ic| enums: [{'age_category': '18 - 35',
#              'country': 'test',
#              'email': 'test_mail@gmail.com',
#              'first_name': 'First',
#              'gender': 'Male',
#              'id': 3726,
#              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#              'last_name': 'Last',
#              'organization': 'Test',
#              'phone_number': '0e15704046',
#              'type': 'ENUMERATOR',
#              'username': 

#   'type': 'ENUMERATOR',
#   'key': 'uuid:5db59e27-bf67-4eb7-a394-f3c8ed4b3030'},
#  {'id': 3726,
#   'first_name': 'First',
#   'last_name': 'Last',
#   'gender': 'Male',
#   'age_category': '18 - 35',
#   'phone_number': '0e15704046',
#   'email': 'test_mail@gmail.com',
#   'country': 'test',
#   'organization': 'Test',
#   'username': 'Mohamud',
#   'type': 'ENUMERATOR',
#   'key': 'uuid:950b07b6-f3dd-4215-a9f0-bce7e1b91f05'}]

# %% [markdown]
# ## farming entity

# %%
farming_entity_list = []
for idx, i in enumerate(cleaned_df.to_dict(orient='records'), start=1):
    farming_entity = {}
    #ic(i['basic_info-organisation_name'])
    farming_entity['id'] = idx
    farming_entity['first_name'] = i['basic_info-organisation_name']
    farming_entity['middle_name'] = i['basic_info-organisation_name']
    farming_entity['last_name'] = i['basic_info-organisation_name']
    farming_entity['organization'] = 'INSTITUTION'
    farming_entity['key'] = i['KEY']
    
    farming_entity_list.append(
        {
            "farmingEntity": farming_entity, 
            'key': i['KEY']
        }
    )
    ic(farming_entity_list)
# Out:
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 7,
#                                              'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 7,
#                                              'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 8,
#                                              'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 7,
#                                              'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 8,
#                                              'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 9,
#                                              'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 7,
#                                              'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 8,
#                                              'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 9,
#                                              'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 10,
#                                              'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 7,
#                                              'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 8,
#                                              'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 9,
#                                              'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 10,
#                                              'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 11,
#                                              'key': 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 7,
#                                              'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 8,
#                                              'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 9,
#                                              'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 10,
#                                              'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 11,
#                                              'key': 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 12,
#                                              'key': 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 5,
#                                              'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:7f209d1a-995b-4b0d-aed3-6d832c69b9a5'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 6,
#                                              'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 7,
#                                              'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:eb135b4a-f771-4daa-91da-87fde5678942'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 8,
#                                              'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:770a9c34-3f77-4a26-a7cb-aa493ab6486a'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 9,
#                                              'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 10,
#                                              'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 11,
#                                              'key': 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 12,
#                                              'key': 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 13,
#                                              'key': 'uuid:3efb2bfc-3c87-4f0b-9309-f556ad16361b',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:3efb2bfc-3c87-4f0b-9309-f556ad16361b'}]
# ic| farming_entity_list: [{'farmingEntity': {'first_name': 'acf',
#                                              'id': 1,
#                                              'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 2,
#                                              'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 3,
#                                              'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4a2d545-66fe-4d23-825b-41025149b460'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 4,
#                                              'key': 'uuid:830f5de7-1fb4-4f13-add2-f825928ef32d',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
# ...
#                            'key': 'uuid:640ddd55-2750-4012-9122-db83305ecc4c'},
#                           {'farmingEntity': {'first_name': 'kaalo',
#                                              'id': 15,
#                                              'key': 'uuid:521dbba3-e777-42bd-afa4-6adf7967a9e3',
#                                              'last_name': 'kaalo',
#                                              'middle_name': 'kaalo',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:521dbba3-e777-42bd-afa4-6adf7967a9e3'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 16,
#                                              'key': 'uuid:f7f737c6-f68a-4016-9fba-78a011e44638',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:f7f737c6-f68a-4016-9fba-78a011e44638'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 17,
#                                              'key': 'uuid:c39544e5-9437-4b4b-b5c4-e9996302eec4',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:c39544e5-9437-4b4b-b5c4-e9996302eec4'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 18,
#                                              'key': 'uuid:d16c462b-885e-49d4-86ab-60d828716e74',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:d16c462b-885e-49d4-86ab-60d828716e74'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 19,
#                                              'key': 'uuid:e00c6211-02a9-45d8-961d-6ff84d480a1b',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:e00c6211-02a9-45d8-961d-6ff84d480a1b'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id':

#                                              'last_name': 'gredo',
#                                              'middle_name': 'gredo',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:d0825aea-557d-40f2-a9b7-573980a05e61'},
#                           {'farmingEntity': {'first_name': 'gredo',
#                                              'id': 41,
#                                              'key': 'uuid:c184fe42-d7d6-4aca-8668-84bc0eef7461',
#                                              'last_name': 'gredo',
#                                              'middle_name': 'gredo',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:c184fe42-d7d6-4aca-8668-84bc0eef7461'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 42,
#                                              'key': 'uuid:c5552452-4596-4494-9874-534580d3ecff',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:c5552452-4596-4494-9874-534580d3ecff'},
#                           {'farmingEntity': {'first_name': 'concern',
#                                              'id': 43,
#                                              'key': 'uuid:4af9be3c-e89c-4487-9f8f-5fde041be91c',
#                                              'last_name': 'concern',
#                                              'middle_name': 'concern',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:4af9be3c-e89c-4487-9f8f-5fde041be91c'},
#                           {'farmingEntity': {'first_name': 'acf',
#                                              'id': 44,
#                                              'key': 'uuid:b4f8fdf0-db8e-4e92-a608-89888fe863d4',
#                                              'last_name': 'acf',
#                                              'middle_name': 'acf',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:b4f8fdf0-db8e-4e92-a608-89888fe863d4'},
#                           {'farmingEntity': {'first_name': 'nrc',
#                                              'id': 45,
#                                              'key': 'uuid:950b07b6-f3dd-4215-a9f0-bce7e1b91f05',
#                                              'last_name': 'nrc',
#                                              'middle_name': 'nrc',
#                                              'organization': 'INSTITUTION'},
#                            'key': 'uuid:950b07b6-f3dd-4215-a9f0-bce7e1b91f05'}]

# %% [markdown]
# ## plot-mcm_details
# - read df to dictionary, for matching keys, extract df values
# ### plot-points
# - parse the geoshape column from cleaned df
# - split and extract the values from each i
# - append to json keys
#
# ## crops
# - get matching rows based on key(id)
# - for these rows if crop has crops, get its values and 'other' if any
#     - every matching rows values are appended to a list(of all crops for that plot)
# - clean 'and' from the crop types
#
# ## differences
# - swales & halfmoon crop column name
# -

# %%
import uuid
import copy
import re

def parse_geoshape(geoshape_str):
    #parse a geoshape string into a list of point dictionaries
    points = []
    parts = geoshape_str.split(';')

    for part in parts:
        part = part.strip()
        if not part:
            continue

        lat, lon, alt, acc = map(float, part.split(' '))

        points.append({
            "longitude": lon,
            "latitude": lat,
            "altitude": alt,
            "accuracy": acc
        })

    return points


plot_list = []
point_id = 1

records = cleaned_df.to_dict(orient='records')

count = 0
#iterate over every i to capture plot details
for idx, i in enumerate(records):
    plot_id = idx + 1
    count += 1

    # ---- BUILD PLOT DETAILS ----
    template_cp = copy.deepcopy(template[0])
    plot_details = template_cp['plot']

    plot_details['id'] = plot_id
    plot_details['key'] = i['KEY']
    plot_details['name'] = uuid.uuid4().hex
    plot_details['calculated_size'] = i['area_ha']
    plot_details['photo_url'] = i['plot_details-photo']
    plot_details['farmingEntityId'] = farming_entity['id']
    plot_details['livestock_allowed'] = False if i['land_use_selection-land_use'] == 'agriculture' else True
    plot_details['conservation_area'] = False

    #get only child row for this key
    matching_child_rows = swales_df[swales_df['PARENT_KEY'] == i['KEY']]
    #matching_child_rows = swales_df[swales_df['PARENT_KEY'] == "uuid:3efb2bfc-3c87-4f0b-9309-f556ad16361b"]

    #holds every row's crops
    all_crops = []
    """----------------------------------CROP STATUS ----------------------------------"""
    #iterate over matching child is to build crop status
    for x in pd.DataFrame(matching_child_rows).to_dict(orient='records'):
        #ic(x['PARENT_KEY'], x["KEY"], x["managements_swales-crops_in_field2"], x["managements_swales-other_crops"])

        if x['managements_swales-crops_present2'] == 'no':
            plot_details['has_crops'] = False
        elif x['managements_swales-crops_present2'] == 'yes':
            plot_details['has_crops'] = True


        #get a list of all crops in field
        if pd.isna(x['managements_swales-crops_in_field2']):
            crop_list = []
        else:
            crop_list = str(x['managements_swales-crops_in_field2']).split(" ")
            ic(crop_list, x['KEY'])


        #check that 'other' crops exist
        if 'other' in crop_list:
            #split by comma or 'and'
            other_crops_value = re.split(r',|\band\b', x['managements_swales-other_crops'])
            #strip whitespace
            other_crops_value = [c.strip() for c in other_crops_value if c.strip()]

            #get rid of 'and' if exists
            if 'and' in other_crops_value:
                other_crops_value.remove('and')

            #only add if not empty
            if other_crops_value != []:
                crop_list.remove('other')
                crop_list.extend(other_crops_value)
                #append crop list for this row to all crops
            all_crops.extend(crop_list)
            ic(all_crops)
        elif 'other' not in crop_list:
            all_crops.extend(crop_list)

        plot_details['crops'] = list(set(all_crops))

        
    """--------------------------------GEOSHAPE PARSING ----------------------------------"""
    geoshape_str = i['plot_details-polygon']
    parsed_points = parse_geoshape(geoshape_str)

    points_list = []
    for p in parsed_points:
        points_list.append({
            "id": point_id,
            "plotId": plot_id,
            "longitude": p["longitude"],
            "latitude": p["latitude"],
            "altitude": p["altitude"],
            "accuracy": p["accuracy"]
        })
        point_id += 1


    """--------------------------------ADMINISTRATIVE DETAILS ----------------------------------"""
    administrative = plot_details['subCounty']
    administrative['subcounty_name'] = i['geography-district_name']
    administrative['county']['county_name'] = i['geography-region_name']


    #update plot_details with number of points and administrative info
    plot_details['points'] = points_list
    plot_details['subCounty'] = administrative
    
    # del plot_details['points']
    # del plot_details['subCounty']
    general_plot = {
        "plot":plot_details, 
        'key':i['KEY']
    }
    #ic(i['KEY'])
    plot_list.append(
        general_plot
    )
# Out:
# ic| crop_list: ['maize', 'cassava', 'sugarcane', 'beans', 'banana', 'tomato', 'other']
#     x['KEY']: 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689/swales/trees_grasses_swales[1]'
# ic| all_crops: ['maize',
#                 'cassava',
#                 'sugarcane',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Mango',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'green pepper',
#                 'watermelon',
#                 'spinach']
# ic| crop_list: ['cassava', 'maize', 'beans', 'banana', 'tomato', 'other']
#     x['KEY']: 'uuid:30c7e4a0-eb6b-4493-913a-ef2c41c43689/swales/trees_grasses_swales[2]'
# ic| all_crops: ['maize',
#                 'cassava',
#                 'sugarcane',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Mango',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'green pepper',
#                 'watermelon',
#                 'spinach',
#                 'cassava',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Sweet potatoes',
#                 'pumpkin',
#                 'green pepper',
#                 'cucumber']
# ic| crop_list: ['maize', 'cassava', 'beans', 'banana', 'coconut', 'other']
#     x['KEY']: 'uuid:eb135b4a-f771-4daa-91da-87fde5678942/swales/trees_grasses_swales[1]'
# ic| all_crops: ['maize', 'cassava', 'beans', 'banana', 'coconut', 'Lemon  Mang']
# ic| crop_list: ['cassava', 'beans', 'banana', 'tomato', 'other']
#     x['KEY']: 'uuid:eb135b4a-f771-4daa-91da-87fde5678942/swales/trees_grasses_swales[2]'
# ic| all_crops: ['maize',
#                 'cassava',
#                 'beans',
#                 'banana',
#                 'coconut',
#                 'Lemon  Mang',
#                 'cassava',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Green pepper',
#                 'cucumber',
#                 'pawpaw']
# ic| crop_list: ['maize', 'beans', 'banana', 'tomato', 'coconut', 'other', 'orange']
#     x['KEY']: 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7/swales/trees_grasses_swales[1]'
# ic| all_crops: ['maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'orange',
#                 'Pawpaw',
#                 'sweet potatoes',
#                 'green pepper',
#                 'chili',
#                 'lemon',
#                 'mango',
#                 'onion',
#                 'Oliva',
#                 'pumpkin']
# ic| crop_list: ['maize', 'beans', 'banana', 'tomato', 'coconut', 'other']
#     x['KEY']: 'uuid:1c3cae44-513f-446d-b718-7d723c19f0b7/swales/trees_grasses_swales[2]'
# ic| all_crops: ['maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'orange',
#                 'Pawpaw',
#                 'sweet potatoes',
#                 'green pepper',
#                 'chili',
#                 'lemon',
#                 'mango',
#                 'onion',
#                 'Oliva',
#                 'pumpkin',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Pawpaw',
#                 'sweet potatoes',
#                 'green pepper',
#                 'chili',
#                 'lemon',
#                 'mango',
#                 'onion',
#                 'Oliva',
#                 'pumpkin']
# ic| crop_list: ['tomato', 'banana', 'beans', 'cassava', 'maize', 'coconut', 'other']
#     x['KEY']: 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39/swales/trees_grasses_swales[1]'
# ic| all_crops: ['tomato',
#                 'banana',
#                 'beans',
#                 'cassava',
#                 'maize',
#                 'coconut',
#                 'Pumpkin',
#                 'cucumber',
#                 'green pepper',
#                 'chilli',
#                 'sesam',
#                 'super napia grass',
#                 'onion',
#                 'lemon',
#                 'olive',
#                 "mango'"]
# ic| crop_list: ['maize', 'cassava', 'beans', 'banana', 'tomato', 'coconut', 'other']
#     x['KEY']: 'uuid:f58c31bf-afe9-41b5-8818-75d9d865ac39/swales/trees_grasses_swales[2]'
# ic| all_crops: ['tomato',
#                 'banana',
#                 'beans',
#                 'cassava',
#                 'maize',
#                 'coconut',
#                 'Pumpkin',
#                 'cucumber',
#                 'green pepper',
#                 'chilli',
#                 'sesam',
#                 'super napia grass',
#                 'onion',
#                 'lemon',
#                 'olive',
#                 "mango'",
#                 'maize',
#                 'cassava',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Pumpkin',
#                 'cucumber',
#                 'green pepper',
#                 'chilli',
#                 'sesam',
#                 'super napia grass',
#                 'onion',
#                 'lemon',
#                 'olive',
#                 "mango'"]
# ic| crop_list: ['maize', 'beans', 'banana', 'tomato', 'coconut', 'other']
#     x['KEY']: 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05/swales/trees_grasses_swales[1]'
# ic| all_crops: ['maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw']
# ic| crop_list: ['maize', 'beans', 'banana', 'tomato', 'other']
#     x['KEY']: 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05/swales/trees_grasses_swales[2]'
# ic| all_crops: ['maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw']
# ic| crop_list: ['maize', 'beans', 'banana', 'tomato', 'other']
#     x['KEY']: 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05/swales/trees_grasses_swales[3]'
# ic| all_crops: ['maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw pumpkin',
#                 'Onion']
# ic| crop_list: ['maize', 'beans', 'banana', 'tomato', 'other']
#     x['KEY']: 'uuid:b1d635d3-db0f-4584-980f-49caa3d03b05/swales/trees_grasses_swales[4]'
# ic| all_crops: ['maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Green pepper',
#                 'chilli',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw pumpkin',
#                 'Onion',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Green pepper',
#                 'chili',
#                 'Oliva',
#                 'lemon',
#                 'sunflower',
#                 'sasem',
#                 'pawpaw']
# ic| crop_list: ['banana', 'beans', 'maize', 'tomato', 'coconut', 'other']
#     x['KEY']: 'uuid:3efb2bfc-3c87-4f0b-9309-f556ad16361b/swales/trees_grasses_swales[1]'
# ic| all_crops: ['banana',
#                 'beans',
#                 'maize',
#                 'tomato',
#                 'coconut',
#                 'Spinach',
#                 'onion',
#                 'salad',
#                 'okra',
#                 'green pepper',
#                 'chili',
#                 'pawpaw',
#                 'mango',
#                 'lemon',
#                 'sesame',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'cucumber',
#                 'watermelon']
# ic| crop_list: ['maize', 'beans', 'banana', 'tomato', 'coconut', 'other']
#     x['KEY']: 'uuid:3efb2bfc-3c87-4f0b-9309-f556ad16361b/swales/trees_grasses_swales[2]'
# ic| all_crops: ['banana',
#                 'beans',
#                 'maize',
#                 'tomato',
#                 'coconut',
#                 'Spinach',
#                 'onion',
#                 'salad',
#                 'okra',
#                 'green pepper',
#                 'chili',
#                 'pawpaw',
#                 'mango',
#                 'lemon',
#                 'sesame',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'cucumber',
#                 'watermelon',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Spinach',
#                 'onion',
#                 'salad',
#                 'okra',
#                 'green pepper',
#                 'chili',
#                 'pawpaw',
#                 'mango',
#                 'lemon',
#                 'sesame',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'cucumber',
#                 'watermelon']
# ic| crop_list: ['sugarcane',
#                 'maize',
#                 'sorghum',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'other']
#     x['KEY']: 'uuid:3efb2bfc-3c87-4f0b-9309-f556ad16361b/swales/trees_grasses_swales[3]'
# ic| all_crops: ['banana',
#                 'beans',
#                 'maize',
#                 'tomato',
#                 'coconut',
#                 'Spinach',
#                 'onion',
#                 'salad',
#                 'okra',
#                 'green pepper',
#                 'chili',
#                 'pawpaw',
#                 'mango',
#                 'lemon',
#                 'sesame',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'cucumber',
#                 'watermelon',
#                 'maize',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Spinach',
#                 'onion',
#                 'salad',
#                 'okra',
#                 'green pepper',
#                 'chili',
#                 'pawpaw',
#                 'mango',
#                 'lemon',
#                 'sesame',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'cucumber',
#                 'watermelon',
#                 'sugarcane',
#                 'maize',
#                 'sorghum',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'coconut',
#                 'Spinach',
#                 'onion',
#                 'salad',
#                 'okra',
#                 'green pepper',
#                 'chili',
#                 'pawpaw',
#                 'mango',
#                 'lemon',
#                 'sesame',
#                 'pumpkin',
#                 'sweet potatoes',
#                 'cucumber',
#                 'watermelon',
#                 'sugarcane',
#                 'Oliva']
# ic| crop_list: ['sorghum', 'banana', 'other']
#     x['KEY']: 'uuid:d16c462b-885e-49d4-86ab-60d828716e74/swales/trees_grasses_swales[1]'
# ic| all_crops: ['sorghum', 'banana', 'Cucumber', 'watermelons']
# ic| crop_list: ['sorghum', 'beans', 'other']
#     x['KEY']: 'uuid:d16c462b-885e-49d4-86ab-60d828716e74/swales/trees_grasses_swales[2]'
# ic| all_crops: ['sorghum',
#                 'banana',
#                 'Cucumber',
#                 'watermelons',
#                 'sorghum',
#                 'beans',
#                 'Cucumber',
#                 'watermelons']
# ic| crop_list: ['maize', 'sorghum', 'beans', 'banana', 'tomato', 'other']
#     x['KEY']: 'uuid:e00c6211-02a9-45d8-961d-6ff84d480a1b/swales/trees_grasses_swales[1]'
# ic| all_crops: ['maize',
#                 'sorghum',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Watermelons',
#                 'peanuts',
#                 'sesame',
#                 'Papaya',
#                 'onions',
#                 'ladyfingers']
# ic| crop_list: ['maize', 'sorghum', 'beans', 'banana', 'other']
#     x['KEY']: 'uuid:e00c6211-02a9-45d8-961d-6ff84d480a1b/swales/trees_grasses_swales[2]'
# ic| all_crops: ['maize',
#                 'sorghum',
#                 'beans',
#                 'banana',
#                 'tomato',
#                 'Watermelons',
#                 'peanuts',
#                 'sesame',
#                 'Papaya',
#                 'onions',
#                 'ladyfingers',
#                 'maize',
#                 'sorghum',
#                 'beans',
#                 'banana',
#                 'Watermelons',
#                 'peanuts',
#                 'sesame',
#                 'Papaya',
#                 'onions',
#                 'ladyfingers']
# ic| crop_list: ['maize', 'sorghum', 'beans', 'tomato']
#     x['KEY']: 'uuid:1d7ebb91-9806-4b99-9229-51aec2513dc5/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:9392c8fa-fbcd-4948-9068-c1a2ae7dc50f/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:b048b1ce-bdd2-4f2b-a9fc-1c4bddafb471/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:258a33b5-0037-4764-bfc3-f9d17634986c/swales/trees_grasses_swales[1]'
# ic| crop_list: ['maize', 'sorghum', 'beans']
#     x['KEY']: 'uuid:74912dcc-e037-4b63-b094-66d6e9b8577f/swales/trees_grasses_swales[1]'
# ic| crop_list: ['maize', 'sorghum', 'beans']
#     x['KEY']: 'uuid:0fbb2a28-501e-4747-ab39-87a7801da25f/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:bab7ac50-49ce-4114-9eb7-c2f2d62cf3b4/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:1a3b1b27-d990-4bfb-a3bd-93de4071689c/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:d58626ab-fa62-4f66-9507-978337140973/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:23774259-a66d-4a03-a1ac-7d5a6c6445b3/swales/trees_grasses_swales[1]'
# ic| crop_list: ['beans', 'sorghum']
#     x['KEY']: 'uuid:08c45549-3c59-4104-a372-b4ce870f4ae1/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:a8fdfe37-243f-441c-91b3-9156dc99c8fb/swales/trees_grasses_swales[1]'
# ic| crop_list: ['maize', 'beans']
#     x['KEY']: 'uuid:68af1fb2-1062-4e4b-ab80-eac113a31c0f/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:583662f0-e5c8-428f-96c8-99ebd4ec812e/swales/trees_grasses_swales[1]'
# ic| crop_list: ['maize', 'sorghum', 'beans']
#     x['KEY']: 'uuid:f174a70e-fef8-4c6a-9af1-1b31ae64f804/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:4ffc56dd-460d-4325-ada6-3aa571863662/swales/trees_grasses_swales[1]'
# ic| crop_list: ['sorghum', 'beans']
#     x['KEY']: 'uuid:d0825aea-557d-40f2-a9b7-573980a05e61/swales/trees_grasses_swales[1]'
# ic| crop_list: ['maize', 'beans']
#     x['KEY']: 'uuid:c184fe42-d7d6-4aca-8668-84bc0eef7461/swales/trees_grasses_swales[1]'

# %%
x = pd.DataFrame(matching_child_rows)
x
# Out:
#    tree_swales-planted_choice2  tree_swales-num_tree_species  \
# 26                        none                           NaN
#
#     tree_swales-num_trees_planted  tree_swales-num_tree_survived  \
# 26                            NaN                            NaN
#
#    tree_swales-swales_trees_species tree_swales-other_swales_trees  \
# 26                              NaN                            NaN
#
#     grass_swales-num_grass_species  grass_swales-kg_grass_seeds  \
# 26                             NaN                          NaN
#
#    grass_swales-swales_grass_species grass_swales-other_swales_grass  ...  \
# 26                               NaN                             NaN  ...
#
#    managements_swales-crops_in_field2 managements_swales-other_crops  \
# 26                                NaN                            NaN
#
#    managements_swales-agricultural_field_state gps-Latitude gps-Longitude  \
# 26                                         NaN     3.147707     43.651344
#
#    gps-Altitude  gps-Accuracy              photo  \
# 26        411.0         5.833  1751878234777.jpg
#
#                                    PARENT_KEY  \
# 26  uuid:950b07b6-f3dd-4215-a9f0-bce7e1b91f05
#
#                                                   KEY
# 26  uuid:950b07b6-f3dd-4215-a9f0-bce7e1b91f05/swal...
#
# [1 rows x 23 columns]

# %%
with open(os.path.join(data_folder, 'to_delete.json'), 'w') as f:
    json.dump(plot_list, f, indent=4)

str(swales_df['managements_swales-crops_in_field2'][0]).split(' ')
# Out:
# ['nan']
