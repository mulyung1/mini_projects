# %%
import os
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
from icecream import ic
import json
from datetime import datetime
from copy import deepcopy
load_dotenv()
# Out:
# True

# %% [markdown]
# ## load variables - waterpoints
# - data folder
# - cleaned_df - for only waterpoints
# - json template
# -

# %%
cd ../
# Out:
# /Users/victor/Documents/projects/mini_projects/regreen_cleaning/brics3_migration

# %%
data_folder = os.path.join(os.getcwd(),'data')
cleaned_csv = os.path.join(data_folder, 'final_range_data.csv')
dff = pd.read_csv(cleaned_csv)

#lambda function to filter for waterpoints
#for each row, is it a list/str, then is 'waterpoints' in it, if so, return the df.
cleaned_df = dff[
    dff["land_use_selection-intervention"]
    .apply(lambda x: isinstance(x, (list, str)) and "water_points" in x)
]

#no waterpoints datasets

TEMPLATE_FILE = os.path.join(data_folder,"halfmoon_json_template.json")
with open(TEMPLATE_FILE, "r") as f:
    template = json.load(f)

# %% [markdown]
# ## check waterpoints count

# %%
x = dff["land_use_selection-intervention"]
count = 0
for idx, i in enumerate(list(x)):
    if 'water_points' in i:
        count += 1
        ic(i, count)

ic('water_points count',len(cleaned_df))
# Out:
# ic| i: 'halfmoons swales water_points', count: 1
# ic| i: 'halfmoons swales soil_bunds water_points', count: 2
# ic| i: 'water_points', count: 3
# ic| i: 'water_points', count: 4
# ic| i: 'water_points', count: 5
# ic| i: 'water_points', count: 6
# ic| i: 'water_points', count: 7
# ic| i: 'water_points', count: 8
# ic| i: 'water_points', count: 9
# ic| i: 'water_points', count: 10
# ic| i: 'water_points', count: 11
# ic| i: 'water_points', count: 12
# ic| i: 'water_points', count: 13
# ic| i: 'water_points', count: 14
# ic| i: 'water_points', count: 15
# ic| i: 'water_points', count: 16
# ic| i: 'water_points', count: 17
# ic| i: 'halfmoons contour_planting water_points', count: 18
# ic| i: 'halfmoons gabions water_points swales gulley_plugging'
#     count: 19
# ic| i: 'water_points', count: 20
# ic| i: 'halfmoons contour_planting water_points rock_dam', count: 21
# ic| i: 'halfmoons water_points', count: 22
# ic| i: 'water_points', count: 23
# ic| i: 'halfmoons water_points invasive_removal', count: 24
# ic| i: 'halfmoons swales water_points', count: 25
# ic| i: 'water_points', count: 26
# ic| i: 'water_points', count: 27
# ic| i: 'water_points', count: 28
# ic| i: 'water_points', count: 29
# ic| i: 'water_points', count: 30
# ic| i: 'water_points', count: 31
# ic| i: 'halfmoons swales contour_planting gulley_plugging water_points'
#     count: 32
# ic| i: 'contour_planting water_points', count: 33
# ic| i: 'halfmoons swales water_points', count: 34
# ic| i: 'water_points', count: 35
# ic| i: 'water_points', count: 36
# ic| i: 'halfmoons water_points', count: 37
# ic| i: 'halfmoons swales soil_bunds contour_planting water_points'
#     count: 38
# ic| i: 'water_points', count: 39
# ic| i: 'water_points', count: 40
# ic| i: 'water_points', count: 41
# ic| i: 'water_points', count: 42
# ic| i: 'water_points', count: 43
# ic| i: 'water_points', count: 44
# ic| i: 'water_points', count: 45
# ic| i: 'water_points', count: 46
# ic| 'water_points count', len(cleaned_df): 46
# ('water_points count', 46)

# %% [markdown]
# ## enumerators

# %%
#sorted(list(dff['basic_info-name'].unique()))
##empty name and key dictionary
names_dict = {}
for idx, row in dff.iterrows():
    #ic({row["KEY"], row["basic_info-name"]})
    names_dict[row["KEY"]] = row["basic_info-name"]
#ic(names_dict)
name_uname_dict = {
    "Zakariye haji ali": "abdullahi.hassan@mardo.org", 
    "Issack Idow Ibrahim": "abdullahi.hassan@mardo.org",
    "Abdullahi Hassan Adan": "abdullahi.hassan@mardo.org",
    "Abdikheir Mohamed": "mukhtar.yusuf23",
    "Abdikheir Mohamed Ali": "mukhtar.yusuf23",
    "Abdikheir Mohamed Dahir": "mukhtar.yusuf23",
    "Ali": "mukhtar.yusuf23",
    "Ali Adan": "mukhtar.yusuf23",
    "Ali Aden": "mukhtar.yusuf23",
    "Fathi": "mukhtar.yusuf23", 
    "Fathi Abdirashid": "mukhtar.yusuf23",
    "Ahmed Omar Hassan": "AhmedOmar",
    "Maria Abdirahman Ali": "AhmedOmar",
    "ABSHIR ABDULLAH ALI": "Ahil",
    "Ahmed Ibrahim": "JubaFoundation",
    "Ahmed Ibrahim Mohamed": "JubaFoundation",
    "Abdiaziz Adan Hassa": "guudow",
    "Abdiaziz Adan Hassan": "guudow",
    "Abdi Hassan Adan": "AbdiHassan",
    "Abdullahi": "sharif1234",
    "Abdirashid Sheikh Mohamed": "NRMO",
    "Abdullahi Sharif": "sharif1234",
    "Abdullahi Sharif LLG": "sharif1234",
    "Abdullahi Sharif Noor LLG": "sharif1234",
    "Abdijalil": "Csxaashi",
    "Abdijalil said": "Csxaashi",
    "Abdikarim Mohamed Ismail": "samandoulgou",
    "Abdikarin Mohamed Ismail": "samandoulgou",
    "Hassan Omar Khadhib": "Khadhib",
    "Hassan Omar Khadhibr": "Khadhib",
    "Jamal Ali": "JamalAli",
    "Jamal Ali Tagal": "JamalAli",
    "Mohamud Abdullahi Ali": "Mohamud",
    "Moulid Abdullahi Abdi": "Moulidwadani",
    "Muktar Mohamednoor Rage": "Mrage1997",
    "Osman Ebey Omar": "iibey",
    "Yusuf Mahi munye": "Mcnbdn617660",
    "abdullahi Sharif LLG": "sharif1234",
    "osman Ebey Omar": "iibey",
}

## match and replace names with usernames
for k, v in names_dict.items():
    for key, value in name_uname_dict.items():
        if v == key:
            names_dict[k] = value
#ic(names_dict)

##enumerator dictionary
enumerator = {
        "id": 3726,
        "first_name": "First",
        "last_name": "Last",
        "gender": "Male",
        "age_category": "18 - 35",
        "phone_number": "0e15704046",
        "email": "test_mail@gmail.com",
        "country": "test",
        "organization": "Test",
        "username": "test",
        "type": "ENUMERATOR"
    }

enums = []
#create enumerator jsons
for key, value in names_dict.items():
    e = deepcopy(enumerator)
    e['username'] = value
    e['key'] = key
    enums.append(e)

#ic(enums)

# %% [markdown]
# ## farming entity

# %%
farming_entity_list = []
for idx, i in enumerate(cleaned_df.to_dict(orient='records'), start=1):
    farming_entity = {}
    #ic(i['basic_info-organisation_name'])
    farming_entity['id'] = idx
    farming_entity['first_name'] = i['basic_info-organisation_name']
    farming_entity['middle_name'] = i['basic_info-organisation_name']
    farming_entity['last_name'] = i['basic_info-organisation_name']
    farming_entity['organization'] = 'INSTITUTION'
    farming_entity['key'] = i['KEY']
    
    farming_entity_list.append(
        {
            "farmingEntity": farming_entity, 
            'key': i['KEY']
        }
    )
    #ic(farming_entity_list)

# %% [markdown]
# ## plot-waterpoints_details
# - read df to dictionary, for matching keys, extract df values
# ### plot-points
# - parse the geoshape column from cleaned df
# - split and extract the values from each i
# - append to json keys
#
# ## crops
# - no need for crop details as repeat is not there

# %%
import uuid
import copy
import re

def parse_geoshape(geoshape_str):
    #parse a geoshape string into a list of point dictionaries
    points = []
    parts = geoshape_str.split(';')

    for part in parts:
        part = part.strip()
        if not part:
            continue

        lat, lon, alt, acc = map(float, part.split(' '))

        points.append({
            "longitude": lon,
            "latitude": lat,
            "altitude": alt,
            "accuracy": acc
        })

    return points

plot_list = []
point_id = 1

records = cleaned_df.to_dict(orient='records')

count = 0
#iterate over every i to capture plot details
for idx, i in enumerate(records):
    plot_id = idx + 1
    count += 1

    # ---- BUILD PLOT DETAILS ----
    template_cp = copy.deepcopy(template[0])
    plot_details = template_cp['plot']

    plot_details['id'] = plot_id
    plot_details['key'] = i['KEY']
    plot_details['name'] = "uuid:" + str(uuid.uuid4())
    plot_details['calculated_size'] = i['area_ha']
    plot_details['photo_url'] = i['plot_details-photo']
    plot_details['farmingEntityId'] = farming_entity['id']
    plot_details['livestock_allowed'] = False if i['land_use_selection-land_use'] == 'agriculture' else True
    plot_details['conservation_area'] = False
    
    #no need for crop details hence
    plot_details['has_crops'] = False

        
    """--------------------------------GEOSHAPE PARSING ----------------------------------"""
    geoshape_str = i['plot_details-polygon']

    parsed_points = parse_geoshape(geoshape_str)

    points_list = []
    for p in parsed_points:
        points_list.append({
            "id": point_id,
            "plotId": plot_id,
            "longitude": p["longitude"],
            "latitude": p["latitude"],
            "altitude": p["altitude"],
            "accuracy": p["accuracy"]
        })
        point_id += 1


    """--------------------------------ADMINISTRATIVE DETAILS ----------------------------------"""
    administrative = plot_details['subCounty']
    administrative['subcounty_name'] = i['geography-district_name']
    administrative['county']['county_name'] = i['geography-region_name']


    #update plot_details with number of points and administrative info
    plot_details['points'] = points_list
    plot_details['subCounty'] = administrative
    
    # del plot_details['points']
    # del plot_details['subCounty']
    general_plot = {
        "plot":plot_details, 
        'key':i['KEY']
    }
    #ic(i['KEY'])
    plot_list.append(
        general_plot
    )
    ic(i)
# Out:
# ic| i: {'AttachmentsExpected': 9,
#         'AttachmentsPresent': 9,
#         'DeviceID': 'collect:ZQdP1Ka82y4QRGHu',
#         'Edits': 0,
#         'FormVersion': 'v13',
#         'KEY': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#         'ReviewState': nan,
#         'Status': nan,
#         'SubmissionDate': '2025-01-12T09:47:15.814Z',
#         'SubmitterID': 120,
#         'SubmitterName': 'Somalia_collector',
#         'area_ha': 0.469631438,
#         'area_m2': 4696.31438,
#         'basic_info-date': '27/12/2024',
#         'basic_info-name': 'Abdullahi Hassan Adan',
#         'basic_info-organisation_name': 'acf',
#         'basic_info-organisation_other': nan,
#         'basins-basin_details-average_size': nan,
#         'basins-basin_details-average_space': nan,
#         'basins-basin_details-date': nan,
#         'basins-basin_details-depth': nan,
#         'basins-basin_details-horizontal_space': nan,
#         'basins-basin_details-length': nan,
#         'basins-basin_details-manages': nan,
#         'basins-basin_details-paid_unpaid_labor': nan,
#         'basins-basin_details-total': nan,
#         'basins-basin_details-type': nan,
#         'basins-basin_details-vertical_space': nan,
#         'basins-basin_details-width': nan,
#         'basins-basin_details-youth_manages': nan,
#         'bunds-bunds_details-average_size': nan,
#         'bunds-bunds_details-date': nan,
#         'bunds-bunds_details-depth': nan,
#         'bunds-bunds_details-length': nan,
#         'bunds-bunds_details-manages': nan,
#         'bunds-bunds_details-paid_unpaid_labor': nan,
#         'bunds-bunds_details-total': nan,
#         'bunds-bunds_details-type': nan,
#         'bunds-bunds_details-width': nan,
#         'bunds-bunds_details-youth_manages': nan,
#         'contour-contour_details-average_size': nan,
#         'contour-contour_details-date': nan,
#         'contour-contour_details-depth': nan,
#         'contour-contour_details-length': nan,
#         'contour-contour_details-manages': nan,
#         'contour-contour_details-paid_unpaid_labor': nan,
#         'contour-contour_details-total': nan,
#         'contour-contour_details-type': nan,
#         'contour-contour_details-width': nan,
#         'contour-contour_details-youth_manages': nan,
#         'end': '2025-01-12T09:44:06.645Z',
#         'gabions-gabions_details-average_size': nan,
#         'gabions-gabions_details-date': nan,
#         'gabions-gabions_details-depth': nan,
#         'gabions-gabions_details-length': nan,
#         'gabions-gabions_details-manages': nan,
#         'gabions-gabions_details-paid_unpaid_labor': nan,
#         'gabions-gabions_details-total': nan,
#         'gabions-gabions_details-type': nan,
#         'gabions-gabions_details-width': nan,
#         'gabions-gabions_details-youth_manages': nan,
#         'geography-community_name': 'dhuuray',
#         'geography-district_name': 'rab dhure',
#         'geography-region_name': 'bakool',
#         'geography-state_name': 'southwest',
#         'geometry': 'POLYGON ((42.90883 4.277699, 42.90815 4.277744, 42.90808 '
#                     '4.277113, 42.90889 4.277302, 42.90883 4.277699))',
#         'halfmoons-halfmoon_details-date': '27/12/2024',
#         'halfmoons-halfmoon_details-depth_decimal': 0.2,
#         'halfmoons-halfmoon_details-halfmoon_type': 'new',
#         'halfmoons-halfmoon_details-length_decimal': 3.0,
#         'halfmoons-halfmoon_details-size': nan,
#         'halfmoons-halfmoon_details-total_halfmoons': 1890.0,
#         'halfmoons-halfmoon_details-width_decimal': 1.5,
#         'halfmoons-halfmoon_details_2-average_space': nan,
#         'halfmoons-halfmoon_details_2-horizontal_space': 3.0,
#         'halfmoons-halfmoon_details_2-manages': 'both',
#         'halfmoons-halfmoon_details_2-paid_unpaid_labor': 'unpaid',
#         'halfmoons-halfmoon_details_2-type_halfmoons': 'demi_lunes',
#         'halfmoons-halfmoon_details_2-vertical_space': 6.0,
#         'halfmoons-halfmoon_details_2-youth_manages': 'yes',
#         'invasive_removal-grass_species': nan,
#         'invasive_removal-invasive_species': nan,
#         'invasive_removal-other_basins_grass': nan,
#         'invasive_removal-other_basins_trees': nan,
#         'invasive_removal-other_invasive_species': nan,
#         'invasive_removal-removal_date': nan,
#         'invasive_removal-removal_frequency': nan,
#         'invasive_removal-removal_methods': nan,
#         'invasive_removal-severity': nan,
#         'invasive_removal-tree_species': nan,
#         'keylines-keyline_details-average_size': nan,
#         'keylines-keyline_details-date': nan,
#         'keylines-keyline_details-depth': nan,
#         'keylines-keyline_details-length': nan,
#         'keylines-keyline_details-manages': nan,
#         'keylines-keyline_details-paid_unpaid_labor': nan,
#         'keylines-keyline_details-total': nan,
#         'keylines-keyline_details-type': nan,
#         'keylines-keyline_details-width': nan,
#         'keylines-keyline_details-youth_manages': nan,
#         'land_use_selection-intervention': 'halfmoons swales water_points',
#         'land_use_selection-land_use': 'rangeland',
#         'land_use_selection-project_name': 'brcis3',
#         'meta-instanceID': 'uuid:f8a33b7a-e769-41f7-b58e-422d1cc80f47',
#         'plot_details-photo': '1736568888717.jpg',
#         'plot_details-polygon': '4.2776992 42.9088313 267.0 2.6; 4.2777442 42.9081516 '
#                                 '269.5 1.371; 4.2771129 42.9080836 267.6 1.4; '
#                                 '4.2773018 42.9088917 270.0 1.4; 4.2776992 42.9088313 '
#                                 '267.0 2.6',
#         'plugging-plug_details-average_size': nan,
#         'plugging-plug_details-date': nan,
#         'plugging-plug_details-depth': nan,
#         'plugging-plug_details-length': nan,
#         'plugging-plug_details-manages': nan,
#         'plugging-plug_details-paid_unpaid_labor': nan,
#         'plugging-plug_details-total': nan,
#         'plugging-plug_details-type': nan,
#         'plugging-plug_details-width': nan,
#         'plugging-plug_details-youth_manages': nan,
#         'rock_dams-average_size': nan,
#         'rock_dams-date': nan,
#         'rock_dams-depth': nan,
#         'rock_dams-gps-Accuracy': nan,
#         'rock_dams-gps-Altitude': nan,
#         'rock_dams-gps-Latitude': nan,
#         'rock_dams-gps-Longitude': nan,
#         'rock_dams-grass_dams-dams_grass_species': nan,
#         'rock_dams-grass_dams-kg_grass_seeds': nan,
#         'rock_dams-grass_dams-num_grass_species': nan,
#         'rock_dams-grass_dams-other_dams_grass': nan,
#         'rock_dams-length': nan,
#         'rock_dams-managements_dams-additional_management7': nan,
#         'rock_dams-managements_dams-agricultural_field_state': nan,
#         'rock_dams-managements_dams-crops_in_field7': nan,
#         'rock_dams-managements_dams-crops_present7': nan,
#         'rock_dams-managements_dams-management_practices': nan,
#         'rock_dams-managements_dams-other_crops': nan,
#         'rock_dams-manages': nan,
#         'rock_dams-paid_unpaid_labor': nan,
#         'rock_dams-photo': nan,
#         'rock_dams-total': nan,
#         'rock_dams-trees_dams-dams_trees_species': nan,
#         'rock_dams-trees_dams-num_tree_species': nan,
#         'rock_dams-trees_dams-num_tree_survived': nan,
#         'rock_dams-trees_dams-num_trees_planted': nan,
#         'rock_dams-trees_dams-other_dams_trees': nan,
#         'rock_dams-trees_dams-planted_choice7': nan,
#         'rock_dams-type': nan,
#         'rock_dams-width': nan,
#         'rock_dams-youth_manages': nan,
#         'start': '2025-01-11T04:13:43.592Z',
#         'swales-swales_details-average_size': nan,
#         'swales-swales_details-date': '21/12/2024',
#         'swales-swales_details-depth': 0.2,
#         'swales-swales_details-length': 100.0,
#         'swales-swales_details-manages': 'both',
#         'swales-swales_details-paid_unpaid_labor': 'unpaid',
#         'swales-swales_details-total': 7.0,
#         'swales-swales_details-type': 'new',
#         'swales-swales_details-width': 0.6,
#         'swales-swales_details-youth_manages': 'yes',
#         'terracing-terrace_details-average_size': nan,
#         'terracing-terrace_details-date': nan,
#         'terracing-terrace_details-depth': nan,
#         'terracing-terrace_details-length': nan,
#         'terracing-terrace_details-manages': nan,
#         'terracing-terrace_details-paid_unpaid_labor': nan,
#         'terracing-terrace_details-total': nan,
#         'terracing-terrace_details-type': nan,
#         'terracing-terrace_details-width': nan,
#         'terracing-terrace_details-youth_manages': nan,
#         'waterpoints-gps-Accuracy': 3.55,
#         'waterpoints-gps-Altitude': 252.0,
#         'waterpoints-gps-Latitude': 4.2760966,
#         'waterpoints-gps-Longitude': 42.9188814,
#         'waterpoints-photo': '1736590424968.jpg',
#         'waterpoints-wp_availability': 'all_year',
#         'waterpoints-wp_avg_distance': '500m_to_1000m',
#         'waterpoints-wp_condition': 'non-functional',
#         'waterpoints-wp_contami_sources': 'none',
#         'waterpoints-wp_depth': 14.0,
#         'waterpoints-wp_facilities': 'pump solar_panels',
#         'waterpoints-wp_ownership': 'communal/village',
#         'waterpoints-wp_protection': 'well_covered',
#         'waterpoints-wp_type': 'well',
#         'waterpoints-wp_usage': 'drinking'}
# ic| i: {'AttachmentsExpected': 8,
#         'AttachmentsPresent': 8,
#         'DeviceID': 'collect:PB2LNOmqvGg1Ekq1',
#         'Edits': 0,
#         'FormVersion': 'v14',
#         'KEY': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#         'ReviewState': nan,
#         'Status': nan,
#         'SubmissionDate': '2025-04-03T15:04:11.501Z',
#         'SubmitterID': 120,
#         'SubmitterName': 'Somalia_collector',
#         'area_ha': 0.000294784,
#         'area_m2': 2.9478381,
#         'basic_info-date': '31/03/2025',
#         'basic_info-name': 'Abdi Hassan Adan',
#         'basic_info-organisation_name': 'acf',
#         'basic_info-organisation_other': nan,
#         'basins-basin_details-average_size': nan,
#         'basins-basin_details-average_space': nan,
#         'basins-basin_details-date': nan,
#         'basins-basin_details-depth': nan,
#         'basins-basin_details-horizontal_space': nan,
#         'basins-basin_details-length': nan,
#         'basins-basin_details-manages': nan,
#         'basins-basin_details-paid_unpaid_labor': nan,
#         'basins-basin_details-total': nan,
#         'basins-basin_details-type': nan,
#         'basins-basin_details-vertical_space': nan,
#         'basins-basin_details-width': nan,
#         'basins-basin_details-youth_manages': nan,
#         'bunds-bunds_details-average_size': nan,
#         'bunds-bunds_details-date': '29/03/2025',
#         'bunds-bunds_details-depth': 0.0,
#         'bunds-bunds_details-length': 0.0,
#         'bunds-bunds_details-manages': 'male',
#         'bunds-bunds_details-paid_unpaid_labor': 'paid',
#         'bunds-bunds_details-total': 0.0,
#         'bunds-bunds_details-type': 'new',
#         'bunds-bunds_details-width': 0.0,
#         'bunds-bunds_details-youth_manages': 'no',
#         'contour-contour_details-average_size': nan,
#         'contour-contour_details-date': nan,
#         'contour-contour_details-depth': nan,
#         'contour-contour_details-length': nan,
#         'contour-contour_details-manages': nan,
#         'contour-contour_details-paid_unpaid_labor': nan,
#         'contour-contour_details-total': nan,
#         'contour-contour_details-type': nan,
#         'contour-contour_details-width': nan,
#         'contour-contour_details-youth_manages': nan,
#         'end': '2025-04-03T14:59:25.650Z',
#         'gabions-gabions_details-average_size': nan,
#         'gabions-gabions_details-date': nan,
#         'gabions-gabions_details-depth': nan,
#         'gabions-gabions_details-length': nan,
#         'gabions-gabions_details-manages': nan,
#         'gabions-gabions_details-paid_unpaid_labor': nan,
#         'gabions-gabions_details-total': nan,
#         'gabions-gabions_details-type': nan,
#         'gabions-gabions_details-width': nan,
#         'gabions-gabions_details-youth_manages': nan,
#         'geography-community_name': 'waajid',
#         'geography-district_name': 'waajid',
#         'geography-region_name': 'bakool',
#         'geography-state_name': 'southwest',
#         'geometry': 'POLYGON ((43.25995 3.803266, 43.25995 3.803287, 43.25995 '
#                     '3.80329, 43.25993 3.803284, 43.25995 3.803266))',
#         'halfmoons-halfmoon_details-date': '29/03/2025',
#         'halfmoons-halfmoon_details-depth_decimal': 0.2,
#         'halfmoons-halfmoon_details-halfmoon_type': 'new',
#         'halfmoons-halfmoon_details-length_decimal': 3.0,
#         'halfmoons-halfmoon_details-size': nan,
#         'halfmoons-halfmoon_details-total_halfmoons': 1050.0,
#         'halfmoons-halfmoon_details-width_decimal': 1.5,
#         'halfmoons-halfmoon_details_2-average_space': nan,
#         'halfmoons-halfmoon_details_2-horizontal_space': 2.0,
#         'halfmoons-halfmoon_details_2-manages': 'both',
#         'halfmoons-halfmoon_details_2-paid_unpaid_labor': 'paid',
#         'halfmoons-halfmoon_details_2-type_halfmoons': 'demi_lunes',
#         'halfmoons-halfmoon_details_2-vertical_space': 1.0,
#         'halfmoons-halfmoon_details_2-youth_manages': 'no',
#         'invasive_removal-grass_species': nan,
#         'invasive_removal-invasive_species': nan,
#         'invasive_removal-other_basins_grass': nan,
#         'invasive_removal-other_basins_trees': nan,
#         'invasive_removal-other_invasive_species': nan,
#         'invasive_removal-removal_date': nan,
#         'invasive_removal-removal_frequency': nan,
#         'invasive_removal-removal_methods': nan,
#         'invasive_removal-severity': nan,
#         'invasive_removal-tree_species': nan,
#         'keylines-keyline_details-average_size': nan,
#         'keylines-keyline_details-date': nan,
#         'keylines-keyline_details-depth': nan,
#         'keylines-keyline_details-length': nan,
#         'keylines-keyline_details-manages': nan,
#         'keylines-keyline_details-paid_unpaid_labor': nan,
#         'keylines-keyline_details-total': nan,
#         'keylines-keyline_details-type': nan,
#         'keylines-keyline_details-width': nan,
#         'keylines-keyline_details-youth_manages': nan,
#         'land_use_selection-intervention': 'halfmoons swales soil_bunds water_points',
#         'land_use_selection-land_use': 'rangeland',
#         'land_use_selection-project_name': 'brcis3',
#         'meta-instanceID': 'uuid:366f2dfd-c43f-4b67-b8a2-b5056ad18b45',
#         'plot_details-photo': '1743404011357.jpg',
#         'plot_details-polygon': '3.8032662 43.2599455 354.9967041015625 4.422; '
#                                 '3.8032873 43.2599473 353.01190185546875 4.054; '
#                                 '3.80329 43.2599451 353.01190185546875 3.893; '
#                                 '3.8032838 43.259928 352.6593017578125 5.314; '
#                                 '3.8032662 43.2599455 354.9967041015625 4.422',
#         'plugging-plug_details-average_size': nan,
#         'plugging-plug_details-date': nan,
#         'plugging-plug_details-depth': nan,
#         'plugging-plug_details-length': nan,
#         'plugging-plug_details-manages': nan,
#         'plugging-plug_details-paid_unpaid_labor': nan,
#         'plugging-plug_details-total': nan,
#         'plugging-plug_details-type': nan,
#         'plugging-plug_details-width': nan,
#         'plugging-plug_details-youth_manages': nan,
#         'rock_dams-average_size': nan,
#         'rock_dams-date': nan,
#         'rock_dams-depth': nan,
#         'rock_dams-gps-Accuracy': nan,
#         'rock_dams-gps-Altitude': nan,
#         'rock_dams-gps-Latitude': nan,
#         'rock_dams-gps-Longitude': nan,
#         'rock_dams-grass_dams-dams_grass_species': nan,
#         'rock_dams-grass_dams-kg_grass_seeds': nan,
#         'rock_dams-grass_dams-num_grass_species': nan,
#         'rock_dams-grass_dams-other_dams_grass': nan,
#         'rock_dams-length': nan,
#         'rock_dams-managements_dams-additional_management7': nan,
#         'rock_dams-managements_dams-agricultural_field_state': nan,
#         'rock_dams-managements_dams-crops_in_field7': nan,
#         'rock_dams-managements_dams-crops_present7': nan,
#         'rock_dams-managements_dams-management_practices': nan,
#         'rock_dams-managements_dams-other_crops': nan,
#         'rock_dams-manages': nan,
#         'rock_dams-paid_unpaid_labor': nan,
#         'rock_dams-photo': nan,
#         'rock_dams-total': nan,
#         'rock_dams-trees_dams-dams_trees_species': nan,
#         'rock_dams-trees_dams-num_tree_species': nan,
#         'rock_dams-trees_dams-num_tree_survived': nan,
#         'rock_dams-trees_dams-num_trees_planted': nan,
#         'rock_dams-trees_dams-other_dams_trees': nan,
#         'rock_dams-trees_dams-planted_choice7': nan,
#         'rock_dams-type': nan,
#         'rock_dams-width': nan,
#         'rock_dams-youth_manages': nan,
#         'start': '2025-03-31T05:09:08.601Z',
#         'swales-swales_details-average_size': nan,
#         'swales-swales_details-date': '29/03/2025',
#         'swales-swales_details-depth': 1.5,
#         'swales-swales_details-length': 100.0,
#         'swales-swales_details-manages': 'both',
#         'swales-swales_details-paid_unpaid_labor': 'paid',
#         'swales-swales_details-total': 2.0,
#         'swales-swales_details-type': 'new',
#         'swales-swales_details-width': 2.0,
#         'swales-swales_details-youth_manages': 'no',
#         'terracing-terrace_details-average_size': nan,
#         'terracing-terrace_details-date': nan,
#         'terracing-terrace_details-depth': nan,
#         'terracing-terrace_details-length': nan,
#         'terracing-terrace_details-manages': nan,
#         'terracing-terrace_details-paid_unpaid_labor': nan,
#         'terracing-terrace_details-total': nan,
#         'terracing-terrace_details-type': nan,
#         'terracing-terrace_details-width': nan,
#         'terracing-terrace_details-youth_manages': nan,
#         'waterpoints-gps-Accuracy': 4.935,
#         'waterpoints-gps-Altitude': 345.4754639,
#         'waterpoints-gps-Latitude': 3.8041133,
#         'waterpoints-gps-Longitude': 43.2599293,
#         'waterpoints-photo': '1743692352912.jpg',
#         'waterpoints-wp_availability': 'all_year',
#         'waterpoints-wp_avg_distance': '100m_to_500m',
#         'waterpoints-wp_condition': 'funtional',
#         'waterpoints-wp_contami_sources': 'none',
#         'waterpoints-wp_depth': 12.0,
#         'waterpoints-wp_facilities': 'solar_panels pump',
#         'waterpoints-wp_ownership': 'communal/village',
#         'waterpoints-wp_protection': 'fenced',
#         'waterpoints-wp_type': 'well',
#         'waterpoints-wp_usage': 'livestock'}
# ic| i: {'AttachmentsExpected': 2,
#         'AttachmentsPresent': 2,
#         'DeviceID': 'collect:bWeHXCfshtndtck7',
#         'Edits': 0,
#         'FormVersion': 'v14',
#         'KEY': 'uuid:052bf8bd-5378-491f-9944-071ff8b9e023',
#         'ReviewState': nan,
#         'Status': nan,
#         'SubmissionDate': '2025-04-02T11:19:36.846Z',
#         'SubmitterID': 120,
#         'SubmitterName': 'Somalia_collector',
#         'area_ha': 1.23e-05,
#         'area_m2': 0.122977527,
#         'basic_info-date': '29/03/2025',
#         'basic_info-name': 'Abdullahi Sharif Noor LLG',
#         'basic_info-organisation_name': 'concern',
#         'basic_info-organisation_other': nan,
#         'basins-basin_details-average_size': nan,
#         'basins-basin_details-average_space': nan,
#         'basins-basin_details-date': nan,
#         'basins-basin_details-depth': nan,
#         'basins-basin_details-horizontal_space': nan,
#         'basins-basin_details-length': nan,
#         'basins-basin_details-manages': nan,
#         'basins-basin_details-paid_unpaid_labor': nan,
#         'basins-basin_details-total': nan,
#         'basins-basin_details-type': nan,
#         'basins-basin_details-vertical_space': nan,
#         'basins-basin_details-width': nan,
#         'basins-basin_details-youth_manages': nan,
#         'bunds-bunds_details-average_size': nan,
#         'bunds-bunds_details-date': nan,
#         'bunds-bunds_details-depth': nan,
#         'bunds-bunds_details-length': nan,
#         'bunds-bunds_details-manages': nan,
#         'bunds-bunds_details-paid_unpaid_labor': nan,
#         'bunds-bunds_details-total': nan,
#         'bunds-bunds_details-type': nan,
#         'bunds-bunds_details-width': nan,
#         'bunds-bunds_details-youth_manages': nan,
#         'contour-contour_details-average_size': nan,
#         'contour-contour_details-date': nan,
#         'contour-contour_details-depth': nan,
#         'contour-contour_details-length': nan,
#         'contour-contour_details-manages': nan,
#         'contour-contour_details-paid_unpaid_labor': nan,
#         'contour-contour_details-total': nan,
#         'contour-contour_details-type': nan,
#         'contour-contour_details-width': nan,
#         'contour-contour_details-youth_manages': nan,
#         'end': '2025-04-02T11:19:34.790Z',
#         'gabions-gabions_details-average_size': nan,
#         'gabions-gabions_details-date': nan,
#         'gabions-gabions_details-depth': nan,
#         'gabions-gabions_details-length': nan,
#         'gabions-gabions_details-manages': nan,
#         'gabions-gabions_details-paid_unpaid_labor': nan,
#         'gabions-gabions_details-total': nan,
#         'gabions-gabions_details-type': nan,
#         'gabions-gabions_details-width': nan,
#         'gabions-gabions_details-youth_manages': nan,
#         'geography-community_name': 'shimbiroole east',
#         'geography-district_name': 'baardhere',
#         'geography-region_name': 'gedo',
#         'geography-state_name': 'jubaland.',
#         'geometry': 'POLYGON ((42.28438 2.338353, 42.28436 2.33846, 42.28437 '
#                     '2.338441, 42.28436 2.338458, 42.28438 2.338353))',
#         'halfmoons-halfmoon_details-date': nan,
#         'halfmoons-halfmoon_details-depth_decimal': nan,
#         'halfmoons-halfmoon_details-halfmoon_type': nan,
#         'halfmoons-halfmoon_details-length_decimal': nan,
#         'halfmoons-halfmoon_details-size': nan,
#         'halfmoons-halfmoon_details-total_halfmoons': nan,
#         'halfmoons-halfmoon_details-width_decimal': nan,
#         'halfmoons-halfmoon_details_2-average_space': nan,
#         'halfmoons-halfmoon_details_2-horizontal_space': nan,
#         'halfmoons-halfmoon_details_2-manages': nan,
#         'halfmoons-halfmoon_details_2-paid_unpaid_labor': nan,
#         'halfmoons-halfmoon_details_2-type_halfmoons': nan,
#         'halfmoons-halfmoon_details_2-vertical_space': nan,
#         'halfmoons-halfmoon_details_2-youth_manages': nan,
#         'invasive_removal-grass_species': nan,
#         'invasive_removal-invasive_species': nan,
#         'invasive_removal-other_basins_grass': nan,
#         'invasive_removal-other_basins_trees': nan,
#         'invasive_removal-other_invasive_species': nan,
#         'invasive_removal-removal_date': nan,
#         'invasive_removal-removal_frequency': nan,
#         'invasive_removal-removal_methods': nan,
#         'invasive_removal-severity': nan,
#         'invasive_removal-tree_species': nan,
#         'keylines-keyline_details-average_size': nan,
#         'keylines-keyline_details-date': nan,
#         'keylines-keyline_details-depth': nan,
#         'keylines-keyline_details-length': nan,
#         'keylines-keyline_details-manages': nan,
#         'keylines-keyline_details-paid_unpaid_labor': nan,
#         'keylines-keyline_details-total': nan,
#         'keylines-keyline_details-type': nan,
#         'keylines-keyline_details-width': nan,
#         'keylines-keyline_details-youth_manages': nan,
#         'land_use_selection-intervention': 'water_points',
#         'land_use_selection-land_use': 'rangeland',
#         'land_use_selection-project_name': 'brcis3',
#         'meta-instanceID': 'uuid:052bf8bd-5378-491f-9944-071ff8b9e023',
#         'plot_details-photo': '1743592632832.jpg',
#         'plot_details-polygon': '2.3383528 42.2843823 71.80000305175781 '
#                                 '56.1;2.3384602 42.2843619 71.80000305175781 '
#                                 '20.509;2.338441 42.2843687 71.80000305175781 '
#                                 '23.292;2.3384576 42.2843632 71.80000305175781 '
#                                 '10.146;2.3383528 42.2843823 71.80000305175781 56.1',
#         'plugging-plug_details-average_size': nan,
#         'plugging-plug_details-date': nan,
#         'plugging-plug_details-depth': nan,
#         'plugging-plug_details-length': nan,
#         'plugging-plug_details-manages': nan,
#         'plugging-plug_details-paid_unpaid_labor': nan,
#         'plugging-plug_details-total': nan,
#         'plugging-plug_details-type': nan,
#         'plugging-plug_details-width': nan,
#         'plugging-plug_details-youth_manages': nan,
#         'rock_dams-average_size': nan,
#         'rock_dams-date': nan,
#         'rock_dams-depth': nan,
#         'rock_dams-gps-Accuracy': nan,
#         'rock_dams-gps-Altitude': nan,
#         'rock_dams-gps-Latitude': nan,
#         'rock_dams-gps-Longitude': nan,
#         'rock_dams-grass_dams-dams_grass_species': nan,
#         'rock_dams-grass_dams-kg_grass_seeds': nan,
#         'rock_dams-grass_dams-num_grass_species': nan,
#         'rock_dams-grass_dams-other_dams_grass': nan,
#         'rock_dams-length': nan,
#         'rock_dams-managements_dams-additional_management7': nan,
#         'rock_dams-managements_dams-agricultural_field_state': nan,
#         'rock_dams-managements_dams-crops_in_field7': nan,
#         'rock_dams-managements_dams-crops_present7': nan,
#         'rock_dams-managements_dams-management_practices': nan,
#         'rock_dams-managements_dams-other_crops': nan,
#         'rock_dams-manages': nan,
#         'rock_dams-paid_unpaid_labor': nan,
#         'rock_dams-photo': nan,
#         'rock_dams-total': nan,
#         'rock_dams-trees_dams-dams_trees_species': nan,
#         'rock_dams-trees_dams-num_tree_species': nan,
#         'rock_dams-trees_dams-num_tree_survived': nan,
#         'rock_dams-trees_dams-num_trees_planted': nan,
#         'rock_dams-trees_dams-other_dams_trees': nan,
#         'rock_dams-trees_dams-planted_choice7': nan,
#         'rock_dams-type': nan,
#         'rock_dams-width': nan,
#         'rock_dams-youth_manages': nan,
#         'start': '2025-04-02T11:16:36.946Z',
#         'swales-swales_details-average_size': nan,
#         'swales-swales_details-date': nan,
#         'swales-swales_details-depth': nan,
#         'swales-swales_details-length': nan,
#         'swales-swales_details-manages': nan,
#         'swales-swales_details-paid_unpaid_labor': nan,
#         'swales-swales_details-total': nan,
#         'swales-swales_details-type': nan,
#         'swales-swales_details-width': nan,
#         'swales-swales_details-youth_manages': nan,
#         'terracing-terrace_details-average_size': nan,
#         'terracing-terrace_details-date': nan,
#         'terracing-terrace_details-depth': nan,
#         'terracing-terrace_details-length': nan,
#         'terracing-terrace_details-manages': nan,
#         'terracing-terrace_details-paid_unpaid_labor': nan,
#         'terracing-terrace_details-total': nan,
#         'terracing-terrace_details-type': nan,
#         'terracing-terrace_details-width': nan,
#         'terracing-terrace_details-youth_manages': nan,
#         'waterpoints-gps-Accuracy': 18.181,
#         'waterpoints-gps-Altitude': 71.80000305,
#         'waterpoints-gps-Latitude': 2.3383745,
#         'waterpoints-gps-Longitude': 42.2843729,
#         'waterpoints-photo': '1743592764936.jpg',
#         'waterpoints-wp_availability': 'all_year',
#         'waterpoints-wp_avg_distance': '100m_to_500m',
#         'waterpoints-wp_condition': 'funtional',
#         'waterpoints-wp_contami_sources': 'not_known',
#         'waterpoints-wp_depth': 4.0,
#         'waterpoints-wp_facilities': 'pump generator windmill solar_panels',
#         'waterpoints-wp_ownership': 'communal/village',
#         'waterpoints-wp_protection': 'fenced',
#         'waterpoints-wp_type': 'other',
#         'waterpoints-wp_usage': 'drinking'}
# ic| i: {'AttachmentsExpected': 2,
#         'AttachmentsPresent': 2,
#         'DeviceID': 'collect:AAL46sMT95Zp0xRT',
#         'Edits': 0,
#         'FormVersion': 'v14',
#         'KEY': 'uuid:7ee1f61b-c3de-4b8a-8c60-45971de2bc84',
#         'ReviewState': nan,
#         'Status': nan,
#         'SubmissionDate': '2025-04-15T08:46:03.883Z',
#         'SubmitterID': 120,
#         'SubmitterName': 'Somalia_collector',
#         'area_ha': 0.003143652,
#         'area_m2': 31.43651913,
#         'basic_info-date': '15/04/2025',
#         'basic_info-name': 'Abdikheir Mohamed',
#         'basic_info-organisation_name': 'concern',
#         'basic_info-organisation_other': nan,
#         'basins-basin_details-average_size': nan,
#         'basins-basin_details-average_space': nan,
#         'basins-basin_details-date': nan,
#         'basins-basin_details-depth': nan,
#         'basins-basin_details-horizontal_space': nan,
#         'basins-basin_details-length': nan,
#         'basins-basin_details-manages': nan,
#         'basins-basin_details-paid_unpaid_labor': nan,
#         'basins-basin_details-total': nan,
#         'basins-basin_details-type': nan,
#         'basins-basin_details-vertical_space': nan,
#         'basins-basin_details-width': nan,
#         'basins-basin_details-youth_manages': nan,
#         'bunds-bunds_details-average_size': nan,
#         'bunds-bunds_details-date': nan,
#         'bunds-bunds_details-depth': nan,
#         'bunds-bunds_details-length': nan,
#         'bunds-bunds_details-manages': nan,
#         'bunds-bunds_details-paid_unpaid_labor': nan,
#         'bunds-bunds_details-total': nan,
#         'bunds-bunds_details-type': nan,
#         'bunds-bunds_details-width': nan,
#         'bunds-bunds_details-youth_manages': nan,
#         'contour-contour_details-average_size': nan,
#         'contour-contour_details-date': nan,
#         'contour-contour_details-depth': nan,
#         'contour-contour_details-length': nan,
#         'contour-contour_details-manages': nan,
#         'contour-contour_details-paid_unpaid_labor': nan,
#         'contour-contour_details-total': nan,
#         'contour-contour_details-type': nan,
#         'contour-contour_details-width': nan,
#         'contour-contour_details-youth_manages': nan,
#         'end': '2025-04-15T08:11:27.746Z',
#         'gabions-gabions_details-average_size': nan,
#         'gabions-gabions_details-date': nan,
#         'gabions-gabions_details-depth': nan,
#         'gabions-gabions_details-length': nan,
#         'gabions-gabions_details-manages': nan,
#         'gabions-gabions_details-paid_unpaid_labor': nan,
#         'gabions-gabions_details-total': nan,
#         'gabions-gabions_details-type': nan,
#         'gabions-gabions_details-width': nan,
#         'gabions-gabions_details-youth_manages': nan,
#         'geography-community_name': 'gawido',
#         'geography-district_name': 'belet hawa',
#         'geography-region_name': 'gedo',
#         'geography-state_name': 'jubaland.',
#         'geometry': 'POLYGON ((41.92784 3.999872, 41.92786 3.99989, 41.92784 3.99991, '
#                     '41.92781 3.999907, 41.92776 3.999858, 41.92784 3.999872))',
#         'halfmoons-halfmoon_details-date': nan,
#         'halfmoons-halfmoon_details-depth_decimal': nan,
#         'halfmoons-halfmoon_details-halfmoon_type': nan,
#         'halfmoons-halfmoon_details-length_decimal': nan,
#         'halfmoons-halfmoon_details-size': nan,
#         'halfmoons-halfmoon_details-total_halfmoons': nan,
#         'halfmoons-halfmoon_details-width_decimal': nan,
#         'halfmoons-halfmoon_details_2-average_space': nan,
#         'halfmoons-halfmoon_details_2-horizontal_space': nan,
#         'halfmoons-halfmoon_details_2-manages': nan,
#         'halfmoons-halfmoon_details_2-paid_unpaid_labor': nan,
#         'halfmoons-halfmoon_details_2-type_halfmoons': nan,
#         'halfmoons-halfmoon_details_2-vertical_space': nan,
#         'halfmoons-halfmoon_details_2-youth_manages': nan,
#         'invasive_removal-grass_species': nan,
#         'invasive_removal-invasive_species': nan,
#         'invasive_removal-other_basins_grass': nan,
#         'invasive_removal-other_basins_trees': nan,
#         'invasive_removal-other_invasive_species': nan,
#         'invasive_removal-removal_date': nan,
#         'invasive_removal-removal_frequency': nan,
#         'invasive_removal-removal_methods': nan,
#         'invasive_removal-severity': nan,
#         'invasive_removal-tree_species': nan,
#         'keylines-keyline_details-average_size': nan,
#         'keylines-keyline_details-date': nan,
#         'keylines-keyline_details-depth': nan,
#         'keylines-keyline_details-length': nan,
#         'keylines-keyline_details-manages': nan,
#         'keylines-keyline_details-paid_unpaid_labor': nan,
#         'keylines-keyline_details-total': nan,
#         'keylines-keyline_details-type': nan,
#         'keylines-keyline_details-width': nan,
#         'keylines-keyline_details-youth_manages': nan,
#         'land_use_selection-intervention': 'water_points',
#         'land_use_selection-land_use': 'communal_land',
#         'land_use_selection-project_name': 'brcis3',
#         'meta-instanceID': 'uuid:7ee1f61b-c3de-4b8a-8c60-45971de2bc84',
#         'plot_details-photo': '1744704517786.jpg',
#         'plot_details-polygon': '3.9998716 41.9278417 170.0 13.0;3.9998899 41.9278624 '
#                                 '162.0 7.75;3.9999098 41.9278438 171.0 4.11;3.9999075 '
#                                 '41.9278106 173.0 4.889;3.9998578 41.9277585 174.0 '
#                                 '3.635;3.9998716 41.9278417 170.0 13.0',
#         'plugging-plug_details-average_size': nan,
#         'plugging-plug_details-date': nan,
#         'plugging-plug_details-depth': nan,
#         'plugging-plug_details-length': nan,
#         'plugging-plug_details-manages': nan,
#         'plugging-plug_details-paid_unpaid_labor': nan,
#         'plugging-plug_details-total': nan,
#         'plugging-plug_details-type': nan,
#         'plugging-plug_details-width': nan,
#         'plugging-plug_details-youth_manages': nan,
#         'rock_dams-average_size': nan,
#         'rock_dams-date': nan,
#         'rock_dams-depth': nan,
#         'rock_dams-gps-Accuracy': nan,
#         'rock_dams-gps-Altitude': nan,
#         'rock_dams-gps-Latitude': nan,
#         'rock_dams-gps-Longitude': nan,
#         'rock_dams-grass_dams-dams_grass_species': nan,
#         'rock_dams-grass_dams-kg_grass_seeds': nan,
#         'rock_dams-grass_dams-num_grass_species': nan,
#         'rock_dams-grass_dams-other_dams_grass': nan,
#         'rock_dams-length': nan,
#         'rock_dams-managements_dams-additional_management7': nan,
#         'rock_dams-managements_dams-agricultural_field_state': nan,
#         'rock_dams-managements_dams-crops_in_field7': nan,
#         'rock_dams-managements_dams-crops_present7': nan,
#         'rock_dams-managements_dams-management_practices': nan,
#         'rock_dams-managements_dams-other_crops': nan,
#         'rock_dams-manages': nan,
#         'rock_dams-paid_unpaid_labor': nan,
#         'rock_dams-photo': nan,
#         'rock_dams-total': nan,
#         'rock_dams-trees_dams-dams_trees_species': nan,
#         'rock_dams-trees_dams-num_tree_species': nan,
#         'rock_dams-trees_dams-num_tree_survived': nan,
#         'rock_dams-trees_dams-num_trees_planted': nan,
#         'rock_dams-trees_dams-other_dams_trees': nan,
#         'rock_dams-trees_dams-planted_choice7': nan,
#         'rock_dams-type': nan,
#         'rock_dams-width': nan,
#         'rock_dams-youth_manages': nan,
#         'start': '2025-04-15T08:01:17.017Z',
#         'swales-swales_details-average_size': nan,
#         'swales-swales_details-date': nan,
#         'swales-swales_details-depth': nan,
#         'swales-swales_details-length': nan,
#         'swales-swales_details-manages': nan,
#         'swales-swales_details-paid_unpaid_labor': nan,
#         'swales-swales_details-total': nan,
#         'swales-swales_details-type': nan,
#         'swales-swales_details-width': nan,
#         'swales-swales_details-youth_manages': nan,
#         'terracing-terrace_details-average_size': nan,
#         'terracing-terrace_details-date': nan,
#         'terracing-terrace_details-depth': nan,
#         'terracing-terrace_details-length': nan,
#         'terracing-terrace_details-manages': nan,
#         'terracing-terrace_details-paid_unpaid_labor': nan,
#         'terracing-terrace_details-total': nan,
#         'terracing-terrace_details-type': nan,
#         'terracing-terrace_details-width': nan,
#         'terracing-terrace_details-youth_manages': nan,
#         'waterpoints-gps-Accuracy': 3.916,
#         'waterpoints-gps-Altitude': 163.0,
#         'waterpoints-gps-Latitude': 3.999842,
#         'waterpoints-gps-Longitude': 41.9277604,
#         'waterpoints-photo': '1744704674793.jpg',
#         'waterpoints-wp_availability': 'all_year',
#         'waterpoints-wp_avg_distance': '1000_to_2000m',
#         'waterpoints-wp_condition': 'funtional',
#         'waterpoints-wp_contami_sources': 'none',
#         'waterpoints-wp_depth': 15.0,
#         'waterpoints-wp_facilities': 'solar_panels',
#         'waterpoints-wp_ownership': 'communal/village',
#         'waterpoints-wp_protection': 'well_covered',
#         'waterpoints-wp_type': 'well',
#         'waterpoints-wp_usage': 'drinking'}
# ic| i: {'AttachmentsExpected': 2,
#         'AttachmentsPresent': 2,
#         'DeviceID': 'collect:AAL46sMT95Zp0xRT',
#         'Edits': 0,
#         'FormVersion': 'v14',
#         'KEY': 'uuid:1b3420d9-b8df-40a9-9613-adb073439659',
#         'ReviewState': nan,
#         'Status': nan,
#         'SubmissionDate': '2025-04-16T07:51:05.633Z',
#         'SubmitterID': 120,
#         'SubmitterName': 'Somalia_collector',
#         'area_ha': 0.196581099,
#         'area_m2': 1965.810995,
#         'basic_info-date': '16/04/2025',
#         'basic_info-name': 'Abdikheir Mohamed',
#         'basic_info-organisation_name': 'concern',
#         'basic_info-organisation_other': nan,
#         'basins-basin_details-average_size': nan,
#         'basins-basin_details-average_space': nan,
#         'basins-basin_details-date': nan,
#         'basins-basin_details-depth': nan,
#         'basins-basin_details-horizontal_space': nan,
#         'basins-basin_details-length': nan,
#         'basins-basin_details-manages': nan,
#         'basins-basin_details-paid_unpaid_labor': nan,
#         'basins-basin_details-total': nan,
#         'basins-basin_details-type': nan,
#         'basins-basin_details-vertical_space': nan,
#         'basins-basin_details-width': nan,
#         'basins-basin_details-youth_manages': nan,
#         'bunds-bunds_details-average_size': nan,
#         'bunds-bunds_details-date': nan,
#         'bunds-bunds_details-depth': nan,
#         'bunds-bunds_details-length': nan,
#         'bunds-bunds_details-manages': nan,
#         'bunds-bunds_details-paid_unpaid_labor': nan,
#         'bunds-bunds_details-total': nan,
#         'bunds-bunds_details-type': nan,
#         'bunds-bunds_details-width': nan,
#         'bunds-bunds_details-youth_manages': nan,
#         'contour-contour_details-average_size': nan,
#         'contour-contour_details-date': nan,
#         'contour-contour_details-depth': nan,
#         'contour-contour_details-length': nan,
#         'contour-contour_details-manages': nan,
#         'contour-contour_details-paid_unpaid_labor': nan,
#         'contour-contour_details-total': nan,
#         'contour-contour_details-type': nan,
#         'contour-contour_details-width': nan,
#         'contour-contour_details-youth_manages': nan,
#         'end': '2025-04-16T07:49:32.333Z',
#         'gabions-gabions_details-average_size': nan,
#         'gabions-gabions_details-date': nan,
#         'gabions-gabions_details-depth': nan,
#         'gabions-gabions_details-length': nan,
#         'gabions-gabions_details-manages': nan,
#         'gabions-gabions_details-paid_unpaid_labor': nan,
#         'gabions-gabions_details-total': nan,
#         'gabions-gabions_details-type': nan,
#         'gabions-gabions_details-width': nan,
#         'gabions-gabions_details-youth_manages': nan,
#         'geography-community_name': 'malkariyey',
#         'geography-district_name': 'belet hawa',
#         'geography-region_name': 'gedo',
#         'geography-state_name': 'jubaland.',
#         'geometry': 'POLYGON ((41.91104 3.979488, 41.91084 3.979808, 41.9108 '
#                     '3.980331, 41.911 3.98058, 41.91104 3.979488))',
#         'halfmoons-halfmoon_details-date': nan,
#         'halfmoons-halfmoon_details-depth_decimal': nan,
#         'halfmoons-halfmoon_details-halfmoon_type': nan,
#         'halfmoons-halfmoon_details-length_decimal': nan,
#         'halfmoons-halfmoon_details-size': nan,
#         'halfmoons-halfmoon_details-total_halfmoons': nan,
#         'halfmoons-halfmoon_details-width_decimal': nan,
#         'halfmoons-halfmoon_details_2-average_space': nan,
#         'halfmoons-halfmoon_details_2-horizontal_space': nan,
#         'halfmoons-halfmoon_details_2-manages': nan,
#         'halfmoons-halfmoon_details_2-paid_unpaid_labor': nan,
#         'halfmoons-halfmoon_details_2-type_halfmoons': nan,
#         'halfmoons-halfmoon_details_2-vertical_space': nan,
#         'halfmoons-halfmoon_details_2-youth_manages': nan,
#         'invasive_removal-grass_species': nan,
#         'invasive_removal-invasive_species': nan,
#         'invasive_removal-other_basins_grass': nan,
#         'invasive_removal-other_basins_trees': nan,
#         'invasive_removal-other_invasive_species': nan,
#         'invasive_removal-removal_date': nan,
#         'invasive_removal-removal_frequency': nan,
#         'invasive_removal-removal_methods': nan,
#         'invasive_removal-severity': nan,
#         'invasive_removal-tree_species': nan,
#         'keylines-keyline_details-average_size': nan,
#         'keylines-keyline_details-date': nan,
#         'keylines-keyline_details-depth': nan,
#         'keylines-keyline_details-length': nan,
#         'keylines-keyline_details-manages': nan,
#         'keylines-keyline_details-paid_unpaid_labor': nan,
#         'keylines-keyline_details-total': nan,
#         'keylines-keyline_details-type': nan,
#         'keylines-keyline_details-width': nan,
#         'keylines-keyline_details-youth_manages': nan,
#         'land_use_selection-intervention': 'water_points',
#         'land_use_selection-land_use': 'communal_land',
#         'land_use_selection-project_name': 'brcis3',
#         'meta-instanceID': 'uuid:1b3420d9-b8df-40a9-9613-adb073439659',
#         'plot_details-photo': '1744789418295.jpg',
#         'plot_details-polygon': '3.9794876 41.9110441 176.0 3.363;3.9798077 '
#                                 '41.9108389 174.0 4.109;3.9803311 41.9108018 180.0 '
#                                 '3.343;3.9805797 41.9109985 171.0 4.61;3.9794876 '
#                                 '41.9110441 176.0 3.363',
#         'plugging-plug_details-average_size': nan,
#         'plugging-plug_details-date': nan,
#         'plugging-plug_details-depth': nan,
#         'plugging-plug_details-length': nan,
#         'plugging-plug_details-manages': nan,
#         'plugging-plug_details-paid_unpaid_labor': nan,
#         'plugging-plug_details-total': nan,
#         'plugging-plug_details-type': nan,
#         'plugging-plug_details-width': nan,
#         'plugging-plug_details-youth_manages': nan,
#         'rock_dams-average_size': nan,
#         'rock_dams-date': nan,
#         'rock_dams-depth': nan,
#         'rock_dams-gps-Accuracy': nan,
#         'rock_dams-gps-Altitude': nan,
#         'rock_dams-gps-Latitude': nan,
#         'rock_dams-gps-Longitude': nan,
#         'rock_dams-grass_dams-dams_grass_species': nan,
#         'rock_dams-grass_dams-kg_grass_seeds': nan,
#         'rock_dams-grass_dams-num_grass_species': nan,
#         'rock_dams-grass_dams-other_dams_grass': nan,
#         'rock_dams-length': nan,
#         'rock_dams-managements_dams-additional_management7': nan,
#         'rock_dams-managements_dams-agricultural_field_state': nan,
#         'rock_dams-managements_dams-crops_in_field7': nan,
#         'rock_dams-managements_dams-crops_present7': nan,
#         'rock_dams-managements_dams-management_practices': nan,
#         'rock_dams-managements_dams-other_crops': nan,
#         'rock_dams-manages': nan,
#         'rock_dams-paid_unpaid_labor': nan,
#         'rock_dams-photo': nan,
#         'rock_dams-total': nan,
#         'rock_dams-trees_dams-dams_trees_species': nan,
#         'rock_dams-trees_dams-num_tree_species': nan,
#         'rock_dams-trees_dams-num_tree_survived': nan,
#         'rock_dams-trees_dams-num_trees_planted': nan,
#         'rock_dams-trees_dams-other_dams_trees': nan,
#         'rock_dams-trees_dams-planted_choice7': nan,
#         'rock_dams-type': nan,
#         'rock_dams-width': nan,
#         'rock_dams-youth_manages': nan,
#         'start': '2025-04-16T07:41:00.336Z',
#         'swales-swales_details-average_size': nan,
#         'swales-swales_details-date': nan,
#         'swales-swales_details-depth': nan,
#         'swales-swales_details-length': nan,
#         'swales-swales_details-manages': nan,
#         'swales-swales_details-paid_unpaid_labor': nan,
#         'swales-swales_details-total': nan,
#         'swales-swales_details-type': nan,
#         'swales-swales_details-width': nan,
#         'swales-swales_details-youth_manages': nan,
#         'terracing-terrace_details-average_size': nan,
#         'terracing-terrace_details-date': nan,
#         'terracing-terrace_details-depth': nan,
#         'terracing-terrace_details-length': nan,
#         'terracing-terrace_details-manages': nan,
#         'terracing-terrace_details-paid_unpaid_labor': nan,
#         'terracing-terrace_details-total': nan,
#         'terracing-terrace_details-type': nan,
#         'terracing-terrace_details-width': nan,
#         'terracing-terrace_details-youth_manages': nan,
#         'waterpoints-gps-Accuracy': 3.2,
#         'waterpoints-gps-Altitude': 172.0,
#         'waterpoints-gps-Latitude': 3.9805075,
#         'waterpoints-gps-Longitude': 41.9113908,
#         'waterpoints-photo': '1744789765833.jpg',
#         'waterpoints-wp_availability': 'wet_season',
#         'waterpoints-wp_avg_distance': '500m_to_1000m',
#         'waterpoints-wp_condition': 'funtional',
#         'waterpoints-wp_contami_sources': 'none',
#         'waterpoints-wp_depth': 2.0,
#         'waterpoints-wp_facilities': 'generator',
#         'waterpoints-wp_ownership': 'others',
#         'waterpoints-wp_protection': 'none',
#         'waterpoints-wp_type': 'other',
#         'waterpoints-wp_usage': 'agriculture'}
# ic| i: {'AttachmentsExpected': 2,
#         'AttachmentsPresent': 2,
#         'DeviceID': 'collect:AAL46sMT95Zp0xRT',
#         'Edits': 0,
#         'FormVersion': 'v14',
#         'KEY': 'uuid:f41eac66-f058-4af4-a34f-16aaad1ef649',
#         'ReviewState': nan,
#         'Status': nan,
#         'SubmissionDate': '2025-04-16T10:03:53.190Z',
#         'SubmitterID': 120,
#         'SubmitterName': 'Somalia_collector',
#         'area_ha': 0.129769053,
#         'area_m2': 1297.69053,
#         'basic_info-date': '16/04/2025',
#         'basic_info-name': 'Abdikheir Mohamed Dahir',
#         'basic_info-organisation_name': 'concern',
#         'basic_info-organisation_other': nan,
#         'basins-basin_details-average_size': nan,
#         'basins-basin_details-average_space': nan,
#         'basins-basin_details-date': nan,
#         'basins-basin_details-depth': nan,
#         'basins-basin_details-horizontal_space': nan,
#         'basins-basin_details-length': nan,
#         'basins-basin_details-manages': nan,
#         'basins-basin_details-paid_unpaid_labor': nan,
#         'basins-basin_details-total': nan,
#         'basins-basin_details-type': nan,
#         'basins-basin_details-vertical_space': nan,
#         'basins-basin_details-width': nan,
#         'basins-basin_details-youth_manages': nan,
#         'bunds-bunds_details-average_size': nan,
#         'bunds-bunds_details-date': nan,
#         'bunds-bunds_details-depth': nan,
#         'bunds-bunds_details-length': nan,
#         'bunds-bunds_details-manages': nan,
#         'bunds-bunds_details-paid_unpaid_labor': nan,
#         'bunds-bunds_details-total': nan,
#         'bunds-bunds_details-type': nan,
#         'bunds-bunds_details-width': nan,
#         'bunds-bunds_details-youth_manages': nan,
#         'contour-contour_details-average_size': nan,
#         'contour-contour_details-date': nan,
#         'contour-contour_details-depth': nan,
#         'contour-contour_details-length': nan,
#         'contour-contour_details-manages': nan,
# ...
#         'gabions-gabions_details-total': nan,
#         'gabions-gabions_details-type': nan,
#         'gabions-gabions_details-width': nan,
#         'gabions-gabions_details-youth_manages': nan,
#         'geography-community_name': 'shimbiroole east',
#         'geography-district_name': 'baardhere',
#         'geography-region_name': 'gedo',
#         'geography-state_name': 'jubaland.',
#         'geometry': 'POLYGON ((42.28439 2.338426, 42.28439 2.338425, 42.28439 '
#                     '2.338422, 42.28439 2.338424, 42.28438 2.338427, 42.28439 '
#                     '2.338426))',
#         'halfmoons-halfmoon_details-date': nan,
#         'halfmoons-halfmoon_details-depth_decimal': nan,
#         'halfmoons-halfmoon_details-halfmoon_type': nan,
#         'halfmoons-halfmoon_details-length_decimal': nan,
#         'halfmoons-halfmoon_details-size': nan,
#         'halfmoons-halfmoon_details-total_halfmoons': nan,
#         'halfmoons-halfmoon_details-width_decimal': nan,
#         'halfmoons-halfmoon_details_2-average_space': nan,
#         'halfmoons-halfmoon_details_2-horizontal_space': nan,
#         'halfmoons-halfmoon_details_2-manages': nan,
#         'halfmoons-halfmoon_details_2-paid_unpaid_labor': nan,
#         'halfmoons-halfmoon_details_2-type_halfmoons': nan,
#         'halfmoons-halfmoon_details_2-vertical_space': nan,
#         'halfmoons-halfmoon_details_2-youth_manages': nan,
#         'invasive_removal-grass_species': nan,
#         'invasive_removal-invasive_species': nan,
#         'invasive_removal-other_basins_grass': nan,
#         'invasive_removal-other_basins_trees': nan,
#         'invasive_removal-other_invasive_species': nan,
#         'invasive_removal-removal_date': nan,
#         'invasive_removal-removal_frequency': nan,
#         'invasive_removal-removal_methods': nan,
#         'invasive_removal-severity': nan,
#         'invasive_removal-tree_species': nan,
#         'keylines-keyline_details-average_size': nan,
#         'keylines-keyline_details-date': nan,
#         'keylines-keyline_details-depth': nan,
#         'keylines-keyline_details-length': nan,
#         'keylines-keyline_details-manages': nan,
#         'keylines-keyline_details-paid_unpaid_labor': nan,
#         'keylines-keyline_details-total': nan,
#         'keylines-keyline_details-type': nan,
#         'keylines-keyline_details-width': nan,
#         'keylines-keyline_details-youth_manages': nan,
#         'land_use_selection-intervention': 'water_points',
#         'land_use_selection-land_use': 'agriculture',
#         'land_use_selection-project_name': 'brcis3',
#         'meta-instanceID': 'uuid:299740bf-34a3-4fa6-9f53-4bb11d27c1c6',
#         'plot_details-photo': '1742455402182.jpg',
#         'plot_details-polygon': '2.3384263 42.2843865 71.80000305175781 20.4; '
#                                 '2.3384254 42.2843864 71.80000305175781 21.601; '
#                                 '2.3384224 42.2843864 71.69999694824219 12.939; '
#                                 '2.3384245 42.2843861 71.80000305175781 7.886; '
#                                 '2.3384272 42.2843836 71.80000305175781 5.228; '
#                                 '2.3384263 42.2843865 71.80000305175781 20.4',
#         'plugging-plug_details-average_size': nan,
#         'plugging-plug_details-date': nan,
#         'plugging-plug_details-depth': nan,
#         'plugging-plug_details-length': nan,
#         'plugging-plug_details-manages': nan,
#         'plugging-plug_details-paid_unpaid_labor': nan,
#         'plugging-plug_details-total': nan,
#         'plugging-plug_details-type': nan,
#         'plugging-plug_details-width': nan,
#         'plugging-plug_details-youth_manages': nan,
#         'rock_dams-average_size': nan,
#         'rock_dams-date': nan,
#         'rock_dams-depth': nan,
#         'rock_dams-gps-Accuracy': nan,
#         'rock_dams-gps-Altitude': nan,
#         'rock_dams-gps-Latitude': nan,
#         'rock_dams-gps-Longitude': nan,
#         'rock_dams-grass_dams-dams_grass_species': nan,
#         'rock_dams-grass_dams-kg_grass_seeds': nan,
#         'rock_dams-grass_dams-num_grass_species': nan,
#         'rock_dams-grass_dams-other_dams_grass': nan,
#         'rock_dams-length': nan,
#         'rock_dams-managements_dams-additional_management7': nan,
#         'rock_dams-managements_dams-agricultural_field_state': nan,
#         'rock_dams-managements_dams-crops_in_field7': nan,
#         'rock_dams-managements_dams-crops_present7': nan,
#         'rock_dams-managements_dams-management_practices': nan,
#         'rock_dams-managements_dams-other_crops': nan,
#         'rock_dams-manages': nan,
#         'rock_dams-paid_unpaid_labor': nan,
#         'rock_dams-photo': nan,
#         'rock_dams-total': nan,
#         'rock_dams-trees_dams-dams_trees_species': nan,
#         'rock_dams-trees_dams-num_tree_species': nan,
#         'rock_dams-trees_dams-num_tree_survived': nan,
#         'rock_dams-trees_dams-num_trees_planted': nan,
#         'rock_dams-trees_dams-other_dams_trees': nan,
#         'rock_dams-trees_dams-planted_choice7': nan,
#         'rock_dams-type': nan,
#         'rock_dams-width': nan,
#         'rock_dams-youth_manages': nan,
#         'start': '2025-03-19T11:14:03.644Z',
#         'swales-swales_details-average_size': nan,
#         'swales-swales_details-date': nan,
#         'swales-swales_details-depth': nan,
#         'swales-swales_details-length': nan,
#         'swales-swales_details-manages': nan,
#         'swales-swales_details-paid_unpaid_labor': nan,
#         'swales-swales_details-total': nan,
#         'swales-swales_details-type': nan,
#         'swales-swales_details-width': nan,
#         'swales-swales_details-youth_manages': nan,
#         'terracing-terrace_details-average_size': nan,
#         'terracing-terrace_details-date': nan,
#         'terracing-terrace_details-depth': nan,
#         'terracing-terrace_details-length': nan,
#         'terracing-terrace_details-manages': nan,
#         'terracing-terrace_details-paid_unpaid_labor': nan,
#         'terracing-terrace_details-total': nan,
#         'terracing-terrace_details-type': nan,
#         'terracing-terrace_details-width': nan,
#         'terracing-terrace_details-youth_manages': nan,
#         'waterpoints-gps-Accuracy': 4.932,
#         'waterpoints-gps-Altitude': 71.80000305,
#         'waterpoints-gps-Latitude': 2.3384798,
#         'waterpoints-gps-Longitude': 42.2842587,
#         'waterpoints-photo': '1742383031929.jpg',
#         'waterpoints-wp_availability': 'all_year',
#         'waterpoints-wp_avg_distance': '100m_to_500m',
#         'waterpoints-wp_condition': 'funtional',
#         'waterpoints-wp_contami_sources': 'agricultural_runoff',
#         'waterpoints-wp_depth': 25.0,
#         'waterpoints-wp_facilities': 'solar_panels',
#         'waterpoints-wp_ownership': 'communal/village',
#         'waterpoints-wp_protection': 'fenced',
#         'waterpoints-wp_type': 'other',
#         'waterpoints-wp_usage': 'drinking'}
# ic| i: {'AttachmentsExpected': 2,
#         'AttachmentsPresent': 2,
#         'DeviceID': 'collect:AAL46sMT95Zp0xRT',
#         'Edits': 0,
#         'FormVersion': 'v14',
#         'KEY': 'uuid:48fdcf2b-86fd-428f-a607-c2b5aab68f56',
#         'ReviewState': nan,
#         'Status': nan,
#         'SubmissionDate': '2025-04-16T10:03:58.395Z',
#         'SubmitterID': 120,
#         'SubmitterName': 'Somalia_collector',
#         'area_ha': 0.07958036,
#         'area_m2': 795.8036045,
#         'basic_info-date': '16/04/2025',
#         'basic_info-name': 'Abdikheir Mohamed',
#         'basic_info-organisation_name': 'concern',
#         'basic_info-organisation_other': nan,
#         'basins-basin_details-average_size': nan,
#         'basins-basin_details-average_space': nan,
#         'basins-basin_details-date': nan,
#         'basins-basin_details-depth': nan,
#         'basins-basin_details-horizontal_space': nan,
#         'basins-basin_details-length': nan,
#         'basins-basin_details-manages': nan,
#         'basins-basin_details-paid_unpaid_labor': nan,
#         'basins-basin_details-total': nan,
#         'basins-basin_details-type': nan,
#         'basins-basin_details-vertical_space': nan,
#         'basins-basin_details-width': nan,
#         'basins-basin_details-youth_manages': nan,
#         'bunds-bunds_details-average_size': nan,
#         'bunds-bunds_details-date': nan,
#         'bunds-bunds_details-depth': nan,
#         'bunds-bunds_details-length': nan,
#         'bunds-bunds_details-manages': nan,
#         'bunds-bunds_details-paid_unpaid_labor': nan,
#         'bunds-bunds_details-total': nan,
#         'bunds-bunds_details-type': nan,
#         'bunds-bunds_details-width': nan,
#         'bunds-bunds_details-youth_manages': nan,
#         'contour-contour_details-average_size': nan,
#         'contour-contour_details-date': nan,
#         'contour-contour_details-depth': nan,
#         'contour-contour_details-length': nan,
#         'contour-contour_details-manages': nan,
#         'contour-contour_details-paid_unpaid_labor': nan,
#         'contour-contour_details-total': nan,
#         'contour-contour_details-type': nan,
#         'contour-contour_details-width': nan,
#         'contour-contour_details-youth_manages': nan,
#         'end': '2025-04-16T08:39:31.330Z',
#         'gabions-gabions_details-average_size': nan,
#         'gabions-gabions_details-date': nan,
#         'gabions-gabions_details-depth': nan,
#         'gabions-gabions_details-length': nan,
#         'gabions-gabions_details-manages': nan,
#         'gabions-gabions_details-paid_unpaid_labor': nan,
#         'gabions-gabions_details-total': nan,
#         'gabions-gabions_details-type': nan,
#         'gabions-gabions_details-width': nan,
#         'gabions-gabions_details-youth_manages': nan,
#         'geography-community_name': 'gawido',
#         'geography-district_name': 'belet hawa',
#         'geography-region_name': 'gedo',
#         'geography-state_name': 'jubaland.',
#         'geometry': 'POLYGON ((41.91455 3.993963, 41.9147 3.994022, 41.91469 '
#                     '3.994406, 41.91462 3.994552, 41.9146 3.994669, 41.91455 '
#                     '3.993963))',
#         'halfmoons-halfmoon_details-date': nan,
#         'halfmoons-halfmoon_details-depth_decimal': nan,
#         'halfmoons-halfmoon_details-halfmoon_type': nan,
#         'halfmoons-halfmoon_details-length_decimal': nan,
#         'halfmoons-halfmoon_details-size': nan,
#         'halfmoons-halfmoon_details-total_halfmoons': nan,
#         'halfmoons-halfmoon_details-width_decimal': nan,
#         'halfmoons-halfmoon_details_2-average_space': nan,
#         'halfmoons-halfmoon_details_2-horizontal_space': nan,
#         'halfmoons-halfmoon_details_2-manages': nan,
#         'halfmoons-halfmoon_details_2-paid_unpaid_labor': nan,
#         'halfmoons-halfmoon_details_2-type_halfmoons': nan,
#         'halfmoons-halfmoon_details_2-vertical_space': nan,
#         'halfmoons-halfmoon_details_2-youth_manages': nan,
#         'invasive_removal-grass_species': nan,
#         'invasive_removal-invasive_species': nan,
#         'invasive_removal-other_basins_grass': nan,
#         'invasive_removal-other_basins_trees': nan,
#         'invasive_removal-other_invasive_species': nan,
#         'invasive_removal-removal_date': nan,
#         'invasive_removal-removal_frequency': nan,
#         'invasive_removal-removal_methods': nan,
#         'invasive_removal-severity': nan,
#         'invasive_removal-tree_species': nan,
#         'keylines-keyline_details-average_size': nan,
#         'keylines-keyline_details-date': nan,
#         'keylines-keyline_details-depth': nan,
#         'keylines-keyline_details-length': nan,
#         'keylines-keyline_details-manages': nan,
#         'keylines-keyline_details-paid_unpaid_labor': nan,
#         'keylines-keyline_details-total': nan,
#         'keylines-keyline_details-type': nan,
#         'keylines-keyline_details-width': nan,
#         'keylines-keyline_details-youth_manages': nan,
#         'land_use_selection-intervention': 'water_points',
#         'land_use_selection-land_use': 'communal_land',
#         'land_use_selection-project_name': 'brcis3',
#         'meta-instanceID': 'uuid:48fdcf2b-86fd-428f-a607-c2b5aab68f56',
#         'plot_details-photo': '1744792604162.jpg',
#         'plot_details-polygon': '3.9939627 41.9145458 176.0 6.5;3.9940218 41.9147031 '
#                                 '171.0 3.662;3.9944063 41.91469 162.0 7.344;3.9945515 '
#                                 '41.9146217 165.0 3.365;3.9946686 41.9146034 166.0 '
#                                 '3.438;3.9939627 41.9145458 176.0 6.5',
#         'plugging-plug_details-average_size': nan,
#         'plugging-plug_details-date': nan,
#         'plugging-plug_details-depth': nan,
#         'plugging-plug_details-length': nan,
#         'plugging-plug_details-manages': nan,
#         'plugging-plug_details-paid_unpaid_labor': nan,
#         'plugging-plug_details-total': nan,
#         'plugging-plug_details-type': nan,
#         'plugging-plug_details-width': nan,
#         'plugging-plug_details-youth_manages': nan,
#         'rock_dams-average_size': nan,
#         'rock_dams-date': nan,
#         'rock_dams-depth': nan,
#         'rock_dams-gps-Accuracy': nan,
#         'rock_dams-gps-Altitude': nan,
#         'rock_dams-gps-Latitude': nan,
#         'rock_dams-gps-Longitude': nan,
#         'rock_dams-grass_dams-dams_grass_species': nan,
#         'rock_dams-grass_dams-kg_grass_seeds': nan,
#         'rock_dams-grass_dams-num_grass_species': nan,
#         'rock_dams-grass_dams-other_dams_grass': nan,
#         'rock_dams-length': nan,
#         'rock_dams-managements_dams-additional_management7': nan,
#         'rock_dams-managements_dams-agricultural_field_state': nan,
#         'rock_dams-managements_dams-crops_in_field7': nan,
#         'rock_dams-managements_dams-crops_present7': nan,
#         'rock_dams-managements_dams-management_practices': nan,
#         'rock_dams-managements_dams-other_crops': nan,
#         'rock_dams-manages': nan,
#         'rock_dams-paid_unpaid_labor': nan,
#         'rock_dams-photo': nan,
#         'rock_dams-total': nan,
#         'rock_dams-trees_dams-dams_trees_species': nan,
#         'rock_dams-trees_dams-num_tree_species': nan,
#         'rock_dams-trees_dams-num_tree_survived': nan,
#         'rock_dams-trees_dams-num_trees_planted': nan,
#         'rock_dams-trees_dams-other_dams_trees': nan,
#         'rock_dams-trees_dams-planted_choice7': nan,
#         'rock_dams-type': nan,
#         'rock_dams-width': nan,
#         'rock_dams-youth_manages': nan,
#         'start': '2025-04-16T08:35:54.496Z',
#         'swales-swales_details-average_size': nan,
#         'swales-swales_details-date': nan,
#         'swales-swales_details-depth': nan,
#         'swales-swales_details-length': nan,
#         'swales-swales_details-manages': nan,
#         'swales-swales_details-paid_unpaid_labor': nan,
#         'swales-swales_details-total': nan,
#         'swales-swales_details-type': nan,
#         'swales-swales_details-width': nan,
#         'swales-swales_details-youth_manages': nan,
#         'terracing-terrace_details-average_size': nan,
#         'terracing-terrace_details-date': nan,
#         'terracing-terrace_details-depth': nan,
#         'terracing-terrace_details-length': nan,
#         'terracing-terrace_details-manages': nan,
#         'terracing-terrace_details-paid_unpaid_labor': nan,
#         'terracing-terrace_details-total': nan,
#         'terracing-terrace_details-type': nan,
#         'terracing-terrace_details-width': nan,
#         'terracing-terrace_details-youth_manages': nan,
#         'waterpoints-gps-Accuracy': 3.9,
#         'waterpoints-gps-Altitude': 172.0,
#         'waterpoints-gps-Latitude': 3.9946875,
#         'waterpoints-gps-Longitude': 41.9145648,
#         'waterpoints-photo': '1744792762524.jpg',
#         'waterpoints-wp_availability': 'wet_season',
#         'waterpoints-wp_avg_distance': '500m_to_1000m',
#         'waterpoints-wp_condition': 'funtional',
#         'waterpoints-wp_contami_sources': 'none',
#         'waterpoints-wp_depth': 2.0,
#         'waterpoints-wp_facilities': 'generator',
#         'waterpoints-wp_ownership': 'others',
#         'waterpoints-wp_protection': 'none',
#         'waterpoints-wp_type': 'other',
#         'waterpoints-wp_usage': 'agriculture'}

# %%
with open(os.path.join(data_folder, 'to_delete.json'), 'w') as f:
    json.dump(plot_list, f, indent=4)

# %% [markdown]
# ## project

# %%
projects_list = []

names =[]
for row in cleaned_df.to_dict(orient='records'):
    name = row['land_use_selection-project_name']
    

    if name == 'terra':
        name = name.upper()
        id = 131
    elif name == 'brcis3':
        name = 'BRCiS III'
        id = 93
    names.extend([name])
    projects_list.append({
        "project": {
            "id": id,
            "project_name": name
        },
        "key": row['KEY']
    })

ic(set(names))
# Out:
# ic| set(names): {'RAF', 'BRCiS III'}
# {'BRCiS III', 'RAF'}

# %% [markdown]
# ## WaterPoints
# missing
# - herbacious cover
# - who manages >> used who established
# - erosion type
# - is_intervention_effective
# - vertical_spacing
# - horizontal_spacing

# %%
waterpoint_list = []


for idx, c in enumerate(records):

    #if c['KEY'] == "uuid:1975a725-83a5-4bdd-8305-35ac65b2cce9":
    """-----------------------------------WPS CHILD DETAILS-------------------------------------"""
    #no invasve child detail

    """-----------------------------------WPS DETAILS-------------------------------------"""

    wps_details = {
        "key": c["KEY"],
        "id": idx,
        "water_point_type": c["waterpoints-wp_type"].capitalize(),
        "water_usage": [i.capitalize() for i in c["waterpoints-wp_usage"].split()],
        "water_condition": [c["waterpoints-wp_condition"].capitalize()],
        "water_facilities": [i.capitalize() for i in c["waterpoints-wp_facilities"].split()],
        "other_facility": "",
        "average_distance": [c["waterpoints-wp_avg_distance"]],
        "water_point_season": [c["waterpoints-wp_availability"].capitalize()],
        "contamination_sources": [c["waterpoints-wp_contami_sources"].capitalize()],
        "water_point_protection": [i.capitalize() for i in c["waterpoints-wp_protection"].split()],
        "photo_url": c["waterpoints-photo"],
        "longitude": c["waterpoints-gps-Longitude"],
        "latitude": c["waterpoints-gps-Latitude"],
        "altitude": c["waterpoints-gps-Altitude"],
        "accuracy": c["waterpoints-gps-Accuracy"],
        "comments": f"wp_depth {c["waterpoints-wp_depth"]} wp_ownership {c["waterpoints-wp_ownership"]}",
        "rangelandEntryId": 2
    }

    waterpoint_list.append(wps_details)
    

wps_list = [{"waterpoint": [i], "key" :i["key"]} for i in waterpoint_list]

# %%
with open(os.path.join(data_folder, 'to_delete.json'), 'w') as f:
    json.dump(wps_list, f, indent=4)

# %% [markdown]
# ## merge components into one json

# %%
# component lists
lists = [farming_entity_list, wps_list,plot_list, projects_list]

# The output dictionary
merged = {}

for lst in lists:
    ic(len(lst))
    for item in lst:
        k = item['key']

        #check if already updated
        if k not in merged:
            merged[k] = {}
            
        #merge the item into the existing dictionary
        merged[k].update(item)

final = list(merged.values())
for i in final:
    #match enumerators
    for l in enums:
        if i['key'] == l['key']:
            i['enumerator'] = l


    i["boma"] = []
    i["cgrazing"] = []
    i["microcatchment"]= []
    i["seedbank"] = []
    i["seeding"] = []
    i["completed"] = True
    i["rangeModuleId"] = 1
    i["currentStep"]= "DONE"
    i["moduleId"] = 6
    i["econtrol"] = []
    i["iremoval"] = []
    i["is_revisit"] = False
    #get the date_collected
    for j in records:
        if i["key"] == j["KEY"]:
            i["date_collected"] = datetime.strptime(j['basic_info-date'], "%d/%m/%Y").strftime("%Y-%m-%d")
    #match project id
    for x in projects_list:
        if i['key'] == x['key']:
            i['projectId'] = x['project']['id']
    #match plot id
    for k in plot_list:
        if i['key'] == k['key']:
            i['plotId'] = k['plot']['id']
    #match farming_entity_id
    for h in farming_entity_list:
        if i['key'] == h['key']:
            i['farmingEntityId'] = h['farmingEntity']['id']
    #match enumerator id
    for e in enums:
        if i['key'] == e['key']:
            i['enumeratorId'] = e['id']


ic(len(final))
# Out:
# ic| len(lst): 46
# ic| len(lst): 46
# ic| len(lst): 46
# ic| len(lst): 46
# ic| len(final): 46
# 46

# %%
with open(os.path.join(data_folder, 'to_delete.json'), 'w') as f:
    json.dump(final, f, indent=4)

# %% [markdown]
# ## clean up keys

# %%
#clean up keys
def remove_keys(obj, key="key"):
    if isinstance(obj, dict):
        obj.pop(key, None)
        for v in obj.values():
            remove_keys(v, key)
    elif isinstance(obj, list):
        for v in obj:
            remove_keys(v, key)
    return obj

finaal = [x for x in final if x['key'] == 'uuid:b4a2d545-66fe-4d23-825b-41025149b460']
finaal = [remove_keys(i) for i in final]

#add id
for idx, c in enumerate(finaal):
    c['id'] = idx + 1

# %%
with open(os.path.join(data_folder, 'to_delete.json'), 'w') as f:
    json.dump(finaal, f, indent=4)

# %%
for i in enumerate(finaal):
    if len(i[1].keys()) != 23:
        ic("ERROR")
    else:
        ic("✅")
# Out:
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
# ic| '✅'
