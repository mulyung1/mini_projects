# %%
import os
from icecream import ic
import pandas as pd
from dotenv import load_dotenv
import sqlalchemy
from sqlalchemy import create_engine
load_dotenv()

ic(os.getcwd())
# Out:
# ic| os.getcwd(): '/home/victor/Documents/projects/regreen_cleaning/brics3_migration'
# '/home/victor/Documents/projects/regreen_cleaning/brics3_migration'

# %% [markdown]
# # The data
# two datasets
# - shared by unit
# - cleaned by providers
#
# **problem**
# - cleaned data is missing username column.
# - generate json to add halfoom data to regreen db
# -
#
# **solution**
# - use plot details as unique key
# - check if all keys are unique
#
# ### cleaned df

# %%
data_folder = os.path.join(os.getcwd(),'data')
cleaned_csv = os.path.join(data_folder, 'final_combined_rangeland_somalia_brics3_raf_terra.csv')
cleaned_df = pd.read_csv(cleaned_csv)
#set(cleaned_df.columns)

# %%
cleaned_df['geometry'].nunique()
# Out:
# 120

# %%
list(cleaned_df[cleaned_df['geometry'].duplicated()]['geometry'].unique())
# Out:
# [nan]

# %% [markdown]
# ### shared df

# %%
shared_csv = os.path.join('data', 'rangeland_somalia_brics3_area_final_data_shared.csv')
shared_df = pd.read_csv(shared_csv)
#set(shared_df.columns)
#shared_df['geometry'].nunique()
shared_df['geometry'].nunique()
# Out:
# 179

# %%
y = set(shared_df.columns) - set(cleaned_df.columns)
y
# Out:
# {'AttachmentsExpected',
#  'AttachmentsPresent',
#  'DeviceID',
#  'Edits',
#  'FormVersion',
#  'KEY',
#  'ReviewState',
#  'Status',
#  'SubmissionDate',
#  'SubmitterID',
#  'SubmitterName',
#  'basic_info-name',
#  'end',
#  'meta-instanceID',
#  'start'}

# %% [markdown]
# ### join the dfs based on geometry(plot) column
# left merge:
# - it keeps all the data from the left DataFrame and adds matching information from the right DataFrame
# - https://medium.com/@whyamit404/understanding-left-merge-in-pandas-03f04cd3cf5f

# %%
merged_df = pd.merge(cleaned_df, shared_df[['geometry','basic_info-name']], on='geometry', how='left')
#merged_df.to_csv(os.path.join(data_folder, 'output2.csv'))
merged_df
# Out:
#     basic_info-date basic_info-organisation_name  \
# 0        15/05/2025                      concern
# 1        29/05/2025                          irc
# 2        17/05/2025                        kaalo
# 3        17/05/2025                        kaalo
# 4        17/05/2025                        kaalo
# ..              ...                          ...
# 303      12/10/2024                          IRC
# 304      12/23/2024                          SCI
# 305      12/23/2024                          SCI
# 306      12/23/2024                          SCI
# 307      12/26/2024                          IRC
#
#      basic_info-organisation_other geography-state_name geography-region_name  \
# 0                              NaN            jubaland.                  gedo
# 1                              NaN             galmudug                 mudug
# 2                              NaN             puntland                mudug.
# 3                              NaN             puntland                mudug.
# 4                              NaN             puntland                mudug.
# ..                             ...                  ...                   ...
# 303                            NaN             galmudug                 Mudug
# 304                            NaN           hirshabele                 Hiran
# 305                            NaN           hirshabele                 Hiran
# 306                            NaN           hirshabele                 Hiran
# 307                            NaN             galmudug                 Mudug
#
#     geography-district_name geography-community_name plot_details-photo  \
# 0                 baardhere              buulo dhato  1749537712661.jpg
# 1                  galkacyo                 dhardhar  1748511134226.jpg
# 2                 galkacyo.               gacmo fale  1747480392579.jpg
# 3                 galkacyo.               gacmo fale  1747479455200.jpg
# 4                 galkacyo.               gacmo fale  1747478430265.jpg
# ..                      ...                      ...                ...
# 303                Galkacyo                 Dhardhar                NaN
# 304              BeletWeyne                   Jawiil                NaN
# 305              BeletWeyne                   Jawiil                NaN
# 306              BeletWeyne                Warqumayo                NaN
# 307                Galkacyo                  Bitaale                NaN
#
#                                   plot_details-polygon  \
# 0    2.352898 42.2954533 70.3623046875 7.324;2.3536...
# 1    6.6435158 46.9506466 320.0 2.0;6.6436798 46.95...
# 2    7.0243358 47.7520651 288.0 7.5; 7.024208 47.75...
# 3    7.0367036 47.7713796 285.0 3.0;7.036829 47.771...
# 4    7.0382631 47.7670073 281.0 3.682; 7.0383558 47...
# ..                                                 ...
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
#
#     land_use_selection-project_name  ... waterpoints-wp_facilities  \
# 0                            brcis3  ...                       NaN
# 1                            brcis3  ...                       NaN
# 2                            brcis3  ...                       NaN
# 3                            brcis3  ...                       NaN
# 4                            brcis3  ...                       NaN
# ..                              ...  ...                       ...
# 303                          brcis3  ...                       NaN
# 304                          brcis3  ...                       NaN
# 305                          brcis3  ...                       NaN
# 306                          brcis3  ...                       NaN
# 307                          brcis3  ...                       NaN
#
#     waterpoints-gps-Latitude waterpoints-gps-Longitude  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 303                 6.644095                 46.951650
# 304                 4.917423                 45.221193
# 305                 4.923309                 45.223448
# 306                 4.994899                 45.160282
# 307                 6.705058                 47.838104
#
#     waterpoints-gps-Altitude  waterpoints-gps-Accuracy  waterpoints-photo  \
# 0                        NaN                       NaN                NaN
# 1                        NaN                       NaN                NaN
# 2                        NaN                       NaN                NaN
# 3                        NaN                       NaN                NaN
# 4                        NaN                       NaN                NaN
# ..                       ...                       ...                ...
# 303                    323.7                     4.725                NaN
# 304                    170.8                     4.400                NaN
# 305                    176.0                     2.400                NaN
# 306                    199.5                     3.600                NaN
# 307                    195.7                     4.900                NaN
#
#                                               geometry        area_m2  \
# 0    POLYGON ((42.29545 2.352898, 42.29368 2.353665...   43376.958180
# 1    POLYGON ((46.95065 6.643516, 46.95053 6.64368,...  168417.837100
# 2    POLYGON ((47.75207 7.024336, 47.75187 7.024208...     130.744739
# 3    POLYGON ((47.77138 7.036704, 47.77153 7.036829...      66.898016
# 4    POLYGON ((47.76701 7.038263, 47.76692 7.038356...    1283.520921
# ..                                                 ...            ...
# 303                                                NaN            NaN
# 304                                                NaN            NaN
# 305                                                NaN            NaN
# 306                                                NaN            NaN
# 307                                                NaN            NaN
#
#        area_ha    basic_info-name
# 0     4.337696          Abdullahi
# 1    16.841784  Ahmed Omar Hassan
# 2     0.013074          Abdijalil
# 3     0.006690          Abdijalil
# 4     0.128352     Abdijalil said
# ..         ...                ...
# 303        NaN                NaN
# 304        NaN                NaN
# 305        NaN                NaN
# 306        NaN                NaN
# 307        NaN                NaN
#
# [308 rows x 169 columns]

# %% [markdown]
# ### get names from db

# %%
# create a db engine
engine = create_engine(os.getenv('DATABASE_URL1'))

#query 
query = '''select id, username, first_name, last_name, email, country from respi_regreeningusers where country in ('Somalia', 'somalia') order by first_name asc;'''

#execute the query and fetch the results
conn = engine.connect()
df = pd.read_sql_query(query, conn)

#close the connection
conn.close()
engine.dispose()

df
# Out:
#        id       username first_name   last_name  \
# 0    3733      abdikafim
# 1    4546          hilal    Abdalla      Hassan
# 2    4307  Abdalla.MARDO    Abdalla      Hassan
# 3     457     AbdiHassan       Abdi        Adan
# 4    1844      adandugsi       Abdi        Aden
# ..    ...            ...        ...         ...
# 168  3203          Saiid      Saiid  Abdirahman
# 169  1834          Shueb      Shueb         Nur
# 170  4305         sundus     sundus     Mohamed
# 171  3725   Mcnbdn617660      Yusuf        Mahi
# 172   455   zamzam.bille     Zamzam       Bille
#
#                                email  country
# 0    abdikafi.mohamud@cpd-africa.org  Somalia
# 1               hilalgs106@gmail.com  Somalia
# 2         ganacsadeabdalla@gmail.com  Somalia
# 3             abdi.shekh07@gmail.com  Somalia
# 4                   abdi.adan@nrc.no  Somalia
# ..                               ...      ...
# 168              Zacksupdi@gmail.com  Somalia
# 169    Shueb.nur@savethechildren.org  Somalia
# 170             sundus.ali@kaalo.org  Somalia
# 171          yusuf.munye@hijra.or.ke  Somalia
# 172              zamzam.bille@nrc.no  Somalia
#
# [173 rows x 6 columns]

# %% [markdown]
# ### get unique names from merged df

# %%
merged_df.drop_duplicates(subset=['basic_info-name'])[['basic_info-name', 'basic_info-organisation_name','land_use_selection-intervention']]
#merged_df[['basic_info-name', 'basic_info-organisation_name','land_use_selection-intervention']]
# Out:
#                basic_info-name basic_info-organisation_name  \
# 0                    Abdullahi                      concern
# 1            Ahmed Omar Hassan                          irc
# 2                    Abdijalil                        kaalo
# 4               Abdijalil said                        kaalo
# 5         Maria Abdirahman Ali                          irc
# 7                          NaN                          nrc
# 8                Ahmed Ibrahim                          nrc
# 12         Hassan Omar Khadhib                          nrc
# 13        Hassan Omar Khadhibr                          nrc
# 14         ABSHIR ABDULLAH ALI                          nrc
# 17       Mohamud Abdullahi Ali                          nrc
# 24                    Ali Aden                      concern
# 26        Abdullahi Sharif LLG                      concern
# 27                    Ali Adan                      concern
# 28   Abdullahi Sharif Noor LLG                      concern
# 29        abdullahi Sharif LLG                      concern
# 30            Abdullahi Sharif                      concern
# 32       Abdikheir Mohamed Ali                      concern
# 33           Abdikheir Mohamed                      concern
# 35     Abdikheir Mohamed Dahir                      concern
# 40                         Ali                      concern
# 41             Jamal Ali Tagal                          acf
# 42                   Jamal Ali                          acf
# 49     Muktar Mohamednoor Rage                          acf
# 57        Abdiaziz Adan Hassan                        gredo
# 59         Abdiaziz Adan Hassa                        gredo
# 65    Abdikarin Mohamed Ismail                        gredo
# 68    Abdikarim Mohamed Ismail                        gredo
# 73   Abdirashid Sheikh Mohamed                        gredo
# 79       Ahmed Ibrahim Mohamed                          nrc
# 80            Yusuf Mahi munye                      concern
# 83       Moulid Abdullahi Abdi                          nrc
# 86                       Fathi                      concern
# 92            Fathi Abdirashid                      concern
# 94           Zakariye haji ali                          acf
# 95       Abdullahi Hassan Adan                          acf
# 97            Abdi Hassan Adan                          acf
# 98         Issack Idow Ibrahim                          acf
# 99             Osman Ebey Omar                      concern
# 101            osman Ebey Omar                      concern
#
#                        land_use_selection-intervention
# 0                                           soil_bunds
# 1                                            halfmoons
# 2                                              gabions
# 4                                              gabions
# 5                                            halfmoons
# 7                                            halfmoons
# 8                                               swales
# 12                                        water_points
# 13                              halfmoons water_points
# 14    halfmoons contour_planting water_points rock_dam
# 17             halfmoons contour_planting water_points
# 24                                        water_points
# 26                                        water_points
# 27                                        water_points
# 28                                        water_points
# 29                                        water_points
# 30                                        water_points
# 32                                        water_points
# 33                                        water_points
# 35                                        water_points
# 40                                          soil_bunds
# 41                                    halfmoons swales
# 42                                    halfmoons swales
# 49                                    halfmoons swales
# 57                    halfmoons swales gulley_plugging
# 59                    halfmoons swales gulley_plugging
# 65                    halfmoons swales gulley_plugging
# 68                    halfmoons swales gulley_plugging
# 73                    halfmoons swales gulley_plugging
# 79                                        water_points
# 80                                        water_points
# 83   halfmoons swales soil_bunds contour_planting w...
# 86                                          soil_bunds
# 92                                          soil_bunds
# 94                                    halfmoons swales
# 95                       halfmoons swales water_points
# 97            halfmoons swales soil_bunds water_points
# 98                       halfmoons swales water_points
# 99                                        water_points
# 101                                       water_points

# %% [markdown]
# ### present names(in db) - halfmoons
# - Jamal Ali Tagal - 3228, acf
# - Muktar Mohamednoor Rage - 1831, acf
# - Abdiaziz Adan Hassan - 3726, gredo
# - Abdikarim Mohamed Ismail - 4247, gredo
# - Abdirashid Sheikh Mohamed - 4548, gredo
#
# ### present names - water_points
# - Hassan Omar Khadhib - 2495, nrc
#
# ### missing names(in db) - halfmoons
# - Ahmed Omar Hassan - irc,
# - Maria Abdirahman Ali - irc
# - NAN - nrc
# - ABSHIR ABDULLAH ALI - nrc
# - Mohamud Abdullahi Ali - nrc
# - Moulid Abdullahi Abdi - nrc
# - Zakariye haji ali - acf
# - Abdullahi Hassan Adan - acf
# - Abdi Hassan Adan - acf
# - Issack Idow Ibrahim - acf
# -
#
# ### missing names - soil bunds
# - Abdullahi - concern
# - Ali - concern
# - Fathi - concern
# - Fathi Abdirashid - concern
#
# ### missing names - gabions
# - Abdijalil Said - kaalo
#
# ### missing names - swales
# - Ahmed Ibrahim - nrc
#
# ### missing names - water_points
# - Ali Aden - concern
# - Abdullahi Sharif LLG - concern
# - Abdikheir Mohamed Ali - concern
# - Abdikheir Mohamed Dahir - concern
# - Ahmed Ibrahim Mohamed - nrc
# - Yusuf Mahi munye - concern
# - Osman Ebey Omar - concern

# %% [markdown]
# ## join the dfs based on waterpoints longitude
# - get the waterpoints(those that dont have polygon geometry)

# %%
wps = cleaned_df[cleaned_df['geometry'].isnull()]
wps
# Out:
#     basic_info-date basic_info-organisation_name  \
# 120       3/22/2024                          SCI
# 121       3/28/2024                          ACF
# 122       3/28/2024                          ACF
# 123       3/31/2024                      Concern
# 124       3/31/2024                      Concern
# ..              ...                          ...
# 303      12/10/2024                          IRC
# 304      12/23/2024                          SCI
# 305      12/23/2024                          SCI
# 306      12/23/2024                          SCI
# 307      12/26/2024                          IRC
#
#      basic_info-organisation_other geography-state_name geography-region_name  \
# 120                            NaN           hirshabele       Middle Shabelle
# 121                            NaN            southwest                Bakool
# 122                            NaN            southwest                Bakool
# 123                            NaN            jubaland.                  Gedo
# 124                            NaN            jubaland.                  Gedo
# ..                             ...                  ...                   ...
# 303                            NaN             galmudug                 Mudug
# 304                            NaN           hirshabele                 Hiran
# 305                            NaN           hirshabele                 Hiran
# 306                            NaN           hirshabele                 Hiran
# 307                            NaN             galmudug                 Mudug
#
#     geography-district_name geography-community_name plot_details-photo  \
# 120                  Jawhar                    Moyko                NaN
# 121              Ceel Berde               Ceel Barde                NaN
# 122              Ceel Berde               Ceel Barde                NaN
# 123               Baardhere                Bula Adey                NaN
# 124               Baardhere               Bula Garas                NaN
# ..                      ...                      ...                ...
# 303                Galkacyo                 Dhardhar                NaN
# 304              BeletWeyne                   Jawiil                NaN
# 305              BeletWeyne                   Jawiil                NaN
# 306              BeletWeyne                Warqumayo                NaN
# 307                Galkacyo                  Bitaale                NaN
#
#     plot_details-polygon land_use_selection-project_name  ...  \
# 120                  NaN                          brcis3  ...
# 121                  NaN                          brcis3  ...
# 122                  NaN                          brcis3  ...
# 123                  NaN                          brcis3  ...
# 124                  NaN                          brcis3  ...
# ..                   ...                             ...  ...
# 303                  NaN                          brcis3  ...
# 304                  NaN                          brcis3  ...
# 305                  NaN                          brcis3  ...
# 306                  NaN                          brcis3  ...
# 307                  NaN                          brcis3  ...
#
#     waterpoints-wp_condition waterpoints-wp_facilities  \
# 120                      NaN                       NaN
# 121                      NaN                       NaN
# 122                      NaN                       NaN
# 123                      NaN                       NaN
# 124                      NaN                       NaN
# ..                       ...                       ...
# 303                      NaN                       NaN
# 304                      NaN                       NaN
# 305                      NaN                       NaN
# 306                      NaN                       NaN
# 307                      NaN                       NaN
#
#     waterpoints-gps-Latitude waterpoints-gps-Longitude  \
# 120                 2.757724                 45.497856
# 121                 4.827528                 43.653343
# 122                 4.827972                 43.656587
# 123                 2.338361                 42.284269
# 124                 2.338430                 42.284234
# ..                       ...                       ...
# 303                 6.644095                 46.951650
# 304                 4.917423                 45.221193
# 305                 4.923309                 45.223448
# 306                 4.994899                 45.160282
# 307                 6.705058                 47.838104
#
#      waterpoints-gps-Altitude  waterpoints-gps-Accuracy  waterpoints-photo  \
# 120                 78.417847                     3.900                NaN
# 121                464.800000                     4.500                NaN
# 122                451.900000                     4.200                NaN
# 123                 69.900002                    11.239                NaN
# 124                 69.900002                    13.599                NaN
# ..                        ...                       ...                ...
# 303                323.700000                     4.725                NaN
# 304                170.800000                     4.400                NaN
# 305                176.000000                     2.400                NaN
# 306                199.500000                     3.600                NaN
# 307                195.700000                     4.900                NaN
#
#      geometry  area_m2 area_ha
# 120       NaN      NaN     NaN
# 121       NaN      NaN     NaN
# 122       NaN      NaN     NaN
# 123       NaN      NaN     NaN
# 124       NaN      NaN     NaN
# ..        ...      ...     ...
# 303       NaN      NaN     NaN
# 304       NaN      NaN     NaN
# 305       NaN      NaN     NaN
# 306       NaN      NaN     NaN
# 307       NaN      NaN     NaN
#
# [188 rows x 168 columns]

# %% [markdown]
# ## get waterpoints that intersect with plot geometry.
# in qgis, >> vector >> data management tools >> join attributes by location
# - join the attributes of waterpoints layer(with no plot geometry) to those of the plot-polygons layer.
# - now you have the key('plot-details_photo') to left merge.
# - why this key?
#     - in shared df, it is present and has collectyor names

# %%
wps_intersecting = pd.read_csv(os.path.join(data_folder, ''))
#wps_merged = pd.merge(wps, shared_df[['waterpoints-gps-Longitude','basic_info-name']], on='waterpoints-gps-Longitude', how='left')
#wps_merged.to_csv(os.path.join(data_folder, 'wps_merged.csv'))
#wps_merged.head()
#shared_df[['waterpoints-gps-Longitude','basic_info-name']]
# Out:
#   basic_info-date basic_info-organisation_name  basic_info-organisation_other  \
# 0       3/22/2024                          SCI                            NaN
# 1       3/28/2024                          ACF                            NaN
# 2       3/28/2024                          ACF                            NaN
# 3       3/31/2024                      Concern                            NaN
# 4       3/31/2024                      Concern                            NaN
#
#   geography-state_name geography-region_name geography-district_name  \
# 0           hirshabele       Middle Shabelle                  Jawhar
# 1            southwest                Bakool              Ceel Berde
# 2            southwest                Bakool              Ceel Berde
# 3            jubaland.                  Gedo               Baardhere
# 4            jubaland.                  Gedo               Baardhere
#
#   geography-community_name plot_details-photo plot_details-polygon  \
# 0                    Moyko                NaN                  NaN
# 1               Ceel Barde                NaN                  NaN
# 2               Ceel Barde                NaN                  NaN
# 3                Bula Adey                NaN                  NaN
# 4               Bula Garas                NaN                  NaN
#
#   land_use_selection-project_name  ... waterpoints-wp_facilities  \
# 0                          brcis3  ...                       NaN
# 1                          brcis3  ...                       NaN
# 2                          brcis3  ...                       NaN
# 3                          brcis3  ...                       NaN
# 4                          brcis3  ...                       NaN
#
#   waterpoints-gps-Latitude waterpoints-gps-Longitude waterpoints-gps-Altitude  \
# 0                 2.757724                 45.497856                78.417847
# 1                 4.827528                 43.653343               464.800000
# 2                 4.827972                 43.656587               451.900000
# 3                 2.338361                 42.284269                69.900002
# 4                 2.338430                 42.284234                69.900002
#
#    waterpoints-gps-Accuracy  waterpoints-photo  geometry  area_m2  area_ha  \
# 0                     3.900                NaN       NaN      NaN      NaN
# 1                     4.500                NaN       NaN      NaN      NaN
# 2                     4.200                NaN       NaN      NaN      NaN
# 3                    11.239                NaN       NaN      NaN      NaN
# 4                    13.599                NaN       NaN      NaN      NaN
#
#   basic_info-name
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 169 columns]

# %% [markdown]
# ## inspect halfmoons json

# %%
import json
with open(os.path.join(data_folder,'halfmoon_json_template.json')) as file:
    data = json.load(file)[0]

list(data.keys())
# Out:
# ['id',
#  'date_collected',
#  'enumeratorId',
#  'projectId',
#  'plotId',
#  'moduleId',
#  'rangeModuleId',
#  'currentStep',
#  'farmingEntityId',
#  'is_revisit',
#  'completed',
#  'boma',
#  'cgrazing',
#  'econtrol',
#  'enumerator',
#  'farmingEntity',
#  'iremoval',
#  'microcatchment',
#  'plot',
#  'project',
#  'seedbank',
#  'seeding',
#  'waterpoint']

# %% [markdown]
# # nested dictionaries are
# -
